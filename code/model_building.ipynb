# %%
import pandas as pd

df = pd.read_pickle('../resources/data/preprocessed/tournament_games.pkl')

df.head()
# Out:
#    winner  season  day_number  team0  team1  prev_matchups  \
# 0       0    2003         134   1421   1411            NaN
# 1       0    2003         136   1112   1436            NaN
# 2       0    2003         136   1113   1272            NaN
# 3       0    2003         136   1141   1166            NaN
# 4       0    2003         136   1143   1301            NaN
#
#    common_opps_win_pct_diff    elo_diff  ordinal_elo_diff    BIH  ...  PGH  \
# 0                       NaN  -31.631037                17  -13.0  ...  NaN
# 1                 -0.333333 -469.244650               133  149.0  ...  NaN
# 2                       NaN  120.473581               -31  -24.0  ...  NaN
# 3                  0.000000  117.657793               -22  -21.0  ...  NaN
# 4                       NaN  -54.718516                22   23.0  ...  NaN
#
#      POM  REW    RTH    SAG  STH  WIL    WLK    WOB    WOL
# 0   -5.0  NaN    6.0    6.0  NaN  NaN    3.0   19.0   26.0
# 1  141.0  NaN  180.0  156.0  NaN  NaN  151.0  162.0  175.0
# 2  -12.0  NaN  -16.0   -8.0  NaN  NaN  -13.0  -21.0  -20.0
# 3  -23.0  NaN  -33.0  -30.0  NaN  NaN  -13.0  -27.0  -32.0
# 4    8.0  NaN   12.0    6.0  NaN  NaN   18.0   22.0   21.0
#
# [5 rows x 30 columns]

# %%
df.sort_values(['season'], inplace=True, ignore_index=True)

df
# Out:
#       winner  season  day_number  team0  team1  prev_matchups  \
# 0          0    2003         134   1421   1411            NaN
# 1          1    2003         152   1400   1393            NaN
# 2          1    2003         154   1242   1393            NaN
# 3          1    2003         137   1447   1338            NaN
# 4          1    2003         137   1335   1329            NaN
# ...      ...     ...         ...    ...    ...            ...
# 2491       0    2022         139   1181   1277            NaN
# 2492       0    2022         139   1222   1228            NaN
# 2493       0    2022         139   1235   1458            NaN
# 2494       0    2022         138   1344   1350            NaN
# 2495       1    2022         154   1314   1242            NaN
#
#       common_opps_win_pct_diff    elo_diff  ordinal_elo_diff    BIH  ...  \
# 0                          NaN  -31.631037                17  -13.0  ...
# 1                     0.333333    6.313840                -1   -1.0  ...
# 2                     0.250000   10.877703                -2   -3.0  ...
# 3                     0.200000  432.036386              -130 -159.0  ...
# 4                    -0.166667   20.988116                -5  -18.0  ...
# ...                        ...         ...               ...    ...  ...
# 2491                  0.000000  -97.442730                15   19.0  ...
# 2492                 -0.250000  -69.925376                11    7.0  ...
# 2493                  0.000000  156.221109               -34  -24.0  ...
# 2494                  0.000000 -204.129479                46   63.0  ...
# 2495                  0.000000  181.965084               -26  -26.0  ...
#
#        PGH    POM   REW    RTH    SAG   STH   WIL    WLK    WOB    WOL
# 0      NaN   -5.0   NaN    6.0    6.0   NaN   NaN    3.0   19.0   26.0
# 1      NaN    8.0   NaN    6.0    7.0   NaN   NaN    7.0   -2.0   -2.0
# 2      NaN   11.0   NaN    7.0    8.0   NaN   NaN   10.0   -3.0   -7.0
# 3      NaN -186.0   NaN -188.0 -171.0   NaN   NaN -145.0 -157.0 -165.0
# 4      NaN  -14.0   NaN  -32.0  -24.0   NaN   NaN  -23.0  -27.0  -31.0
# ...    ...    ...   ...    ...    ...   ...   ...    ...    ...    ...
# 2491  11.0   27.0  27.0   13.0   16.0  16.0  12.0   22.0   11.0   13.0
# 2492   8.0   12.0   9.0    6.0   10.0  10.0   3.0    9.0    8.0    8.0
# 2493 -30.0  -12.0 -40.0  -15.0  -40.0 -20.0 -21.0  -27.0  -29.0  -26.0
# 2494  60.0   35.0  78.0   70.0   41.0  54.0  68.0   47.0   59.0   61.0
# 2495 -27.0  -24.0 -24.0  -34.0  -22.0 -29.0 -34.0  -25.0  -32.0  -31.0
#
# [2496 rows x 30 columns]

# %%
df.drop(columns=['day_number', 'team0', 'team1'], inplace=True)

df.head()
# Out:
#    winner  season  prev_matchups  common_opps_win_pct_diff    elo_diff  \
# 0       0    2003            NaN                       NaN  -31.631037
# 1       1    2003            NaN                  0.333333    6.313840
# 2       1    2003            NaN                  0.250000   10.877703
# 3       1    2003            NaN                  0.200000  432.036386
# 4       1    2003            NaN                 -0.166667   20.988116
#
#    ordinal_elo_diff    BIH    COL  DCI  DOK  ...  PGH    POM  REW    RTH  \
# 0                17  -13.0   -1.0  NaN  NaN  ...  NaN   -5.0  NaN    6.0
# 1                -1   -1.0    5.0  NaN  NaN  ...  NaN    8.0  NaN    6.0
# 2                -2   -3.0    2.0  NaN  NaN  ...  NaN   11.0  NaN    7.0
# 3              -130 -159.0 -118.0  NaN  NaN  ...  NaN -186.0  NaN -188.0
# 4                -5  -18.0  -24.0  NaN  NaN  ...  NaN  -14.0  NaN  -32.0
#
#      SAG  STH  WIL    WLK    WOB    WOL
# 0    6.0  NaN  NaN    3.0   19.0   26.0
# 1    7.0  NaN  NaN    7.0   -2.0   -2.0
# 2    8.0  NaN  NaN   10.0   -3.0   -7.0
# 3 -171.0  NaN  NaN -145.0 -157.0 -165.0
# 4  -24.0  NaN  NaN  -23.0  -27.0  -31.0
#
# [5 rows x 27 columns]

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score, log_loss
# from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

predictions = []
feature_importances = []

for season in df['season'].unique():
    print(season)
    
    # s = MinMaxScaler()
    
    # split to in-sample and out-of-sample
    df_is = df.loc[~df['season'].isin([season]), :].reset_index(drop=True)
    df_oos = df.loc[df['season'].isin([season]), :].reset_index(drop=True)
    
    # train model
    eval_years = np.random.choice(df_is['season'].unique(), 5, replace=False)
    df_eval = df_is.loc[df_is['season'].isin(eval_years), :].reset_index(drop=True)
    df_train = df_is.loc[~df_is['season'].isin(eval_years), :].reset_index(drop=True)
    
    X_train = df_train.drop(columns=['winner', 'season'])
    # X_train = s.fit_transform(X_train)
    y_train = df_train['winner']
    
    X_eval = df_eval.drop(columns=['winner', 'season'])
    # X_eval = s.transform(X_eval)
    y_eval = df_eval['winner']    
    
    mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2000, 
                                    max_depth=1, eta=0.01)
    mod.fit(X_train, y_train, verbose=False, early_stopping_rounds=25, 
            eval_metric='logloss', eval_set=[(X_eval, y_eval)])
    
    
    # get out-of-sample predictions
    X_oos = df_oos.drop(columns=['winner', 'season'])
    # X_oos = s.transform(X_oos)
    y_oos = df_oos['winner']
    prediction = mod.predict_proba(X_oos)[:, 1]
    predictions.append(prediction)
    feature_importances.append(mod.feature_importances_)
    
    print(f"{season} Accuracy: {(y_oos == prediction.round()).mean():.2f}")
    print(f"{season} AUC: {roc_auc_score(y_oos, prediction):.2f}")
    print(f"{season} Logloss: {log_loss(y_oos, prediction):.2f}")
    
    print()
    
predictions = np.concatenate(predictions)
feature_importances = np.array(feature_importances).mean(axis=0)
    
'Done'
# Out:
# C:\Users\mhugh\anaconda3\envs\clean\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2003
# 2003 Accuracy: 0.69
# 2003 AUC: 0.79
# 2003 Logloss: 0.53
#
# 2004
# 2004 Accuracy: 0.72
# 2004 AUC: 0.79
# 2004 Logloss: 0.55
#
# 2005
# 2005 Accuracy: 0.72
# 2005 AUC: 0.83
# 2005 Logloss: 0.52
#
# 2006
# 2006 Accuracy: 0.72
# 2006 AUC: 0.78
# 2006 Logloss: 0.56
#
# 2007
# 2007 Accuracy: 0.78
# 2007 AUC: 0.87
# 2007 Logloss: 0.47
#
# 2008
# 2008 Accuracy: 0.74
# 2008 AUC: 0.85
# 2008 Logloss: 0.50
#
# 2009
# 2009 Accuracy: 0.72
# 2009 AUC: 0.83
# 2009 Logloss: 0.50
#
# 2010
# 2010 Accuracy: 0.70
# 2010 AUC: 0.76
# 2010 Logloss: 0.57
#
# 2011
# 2011 Accuracy: 0.62
# 2011 AUC: 0.70
# 2011 Logloss: 0.62
#
# 2012
# 2012 Accuracy: 0.75
# 2012 AUC: 0.79
# 2012 Logloss: 0.57
#
# 2013
# 2013 Accuracy: 0.68
# 2013 AUC: 0.72
# 2013 Logloss: 0.62
#
# 2014
# 2014 Accuracy: 0.63
# 2014 AUC: 0.75
# 2014 Logloss: 0.58
#
# 2015
# 2015 Accuracy: 0.76
# 2015 AUC: 0.83
# 2015 Logloss: 0.52
#
# 2016
# 2016 Accuracy: 0.75
# 2016 AUC: 0.80
# 2016 Logloss: 0.55
#
# 2017
# 2017 Accuracy: 0.75
# 2017 AUC: 0.79
# 2017 Logloss: 0.53
#
# 2018
# 2018 Accuracy: 0.67
# 2018 AUC: 0.77
# 2018 Logloss: 0.59
#
# 2019
# 2019 Accuracy: 0.73
# 2019 AUC: 0.82
# 2019 Logloss: 0.51
#
# 2021
# 2021 Accuracy: 0.66
# 2021 AUC: 0.70
# 2021 Logloss: 0.64
#
# 2022
# 2022 Accuracy: 0.67
# 2022 AUC: 0.71
# 2022 Logloss: 0.63
# 'Done'

# %%
(df['winner'] == predictions.round()).mean()
# Out:
# 0.7075320512820513

# %%
roc_auc_score(df['winner'], predictions)
# Out:
# 0.7819032888519066

# %%
log_loss(df['winner'], predictions)
# Out:
# 0.5571607327684223

# %%
features = pd.DataFrame({'feature': X_oos.columns, 
                         'importance': feature_importances}).sort_values(['importance'], 
                                                                         ascending=False, 
                                                                         ignore_index=True)

features
# Out:
#                      feature  importance
# 0                        SAG    0.355183
# 1                        WLK    0.138080
# 2                        POM    0.134610
# 3                        MOR    0.113976
# 4                   elo_diff    0.076042
# 5                        COL    0.056669
# 6                        RTH    0.036871
# 7                        DOL    0.026579
# 8           ordinal_elo_diff    0.017120
# 9                        WOL    0.008995
# 10                       DCI    0.005922
# 11  common_opps_win_pct_diff    0.005624
# 12                       LMC    0.005326
# 13                       REW    0.003051
# 14                       WIL    0.002937
# 15                       DOK    0.002458
# 16                       KRA    0.002006
# 17                       BIH    0.001947
# 18                       PGH    0.001633
# 19                       MAS    0.001136
# 20             prev_matchups    0.000983
# 21                       KPK    0.000940
# 22                       STH    0.000858
# 23                       DUN    0.000740
# 24                       WOB    0.000315

# %%
df.drop(columns=features.loc[features['importance'] < 0.01, 'feature'], inplace=True)

df
# Out:
#       winner  season    elo_diff  ordinal_elo_diff    COL    DOL    MOR  \
# 0          0    2003  -31.631037                17   -1.0  -19.0   16.0
# 1          1    2003    6.313840                -1    5.0   -2.0    9.0
# 2          1    2003   10.877703                -2    2.0   -6.0   19.0
# 3          1    2003  432.036386              -130 -118.0 -142.0 -187.0
# 4          1    2003   20.988116                -5  -24.0   -7.0  -54.0
# ...      ...     ...         ...               ...    ...    ...    ...
# 2491       0    2022  -97.442730                15   14.0   13.0   18.0
# 2492       0    2022  -69.925376                11   13.0    8.0   15.0
# 2493       0    2022  156.221109               -34  -39.0  -19.0  -19.0
# 2494       0    2022 -204.129479                46   54.0   57.0   29.0
# 2495       1    2022  181.965084               -26  -26.0  -23.0  -29.0
#
#         POM    RTH    SAG    WLK
# 0      -5.0    6.0    6.0    3.0
# 1       8.0    6.0    7.0    7.0
# 2      11.0    7.0    8.0   10.0
# 3    -186.0 -188.0 -171.0 -145.0
# 4     -14.0  -32.0  -24.0  -23.0
# ...     ...    ...    ...    ...
# 2491   27.0   13.0   16.0   22.0
# 2492   12.0    6.0   10.0    9.0
# 2493  -12.0  -15.0  -40.0  -27.0
# 2494   35.0   70.0   41.0   47.0
# 2495  -24.0  -34.0  -22.0  -25.0
#
# [2496 rows x 11 columns]

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score, log_loss
# from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

predictions = []
feature_importances = []

for season in df['season'].unique():
    print(season)
    
    # s = MinMaxScaler()
    
    # split to in-sample and out-of-sample
    df_is = df.loc[~df['season'].isin([season]), :].reset_index(drop=True)
    df_oos = df.loc[df['season'].isin([season]), :].reset_index(drop=True)
    
    # train model
    eval_years = np.random.choice(df_is['season'].unique(), 5, replace=False)
    df_eval = df_is.loc[df_is['season'].isin(eval_years), :].reset_index(drop=True)
    df_train = df_is.loc[~df_is['season'].isin(eval_years), :].reset_index(drop=True)
    
    X_train = df_train.drop(columns=['winner', 'season'])
    # X_train = s.fit_transform(X_train)
    y_train = df_train['winner']
    
    X_eval = df_eval.drop(columns=['winner', 'season'])
    # X_eval = s.transform(X_eval)
    y_eval = df_eval['winner']    
    
    mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2000, 
                                    max_depth=1, eta=0.01)
    mod.fit(X_train, y_train, verbose=False, early_stopping_rounds=25, 
            eval_metric='logloss', eval_set=[(X_eval, y_eval)])
    
    
    # get out-of-sample predictions
    X_oos = df_oos.drop(columns=['winner', 'season'])
    # X_oos = s.transform(X_oos)
    y_oos = df_oos['winner']
    prediction = mod.predict_proba(X_oos)[:, 1]
    predictions.append(prediction)
    feature_importances.append(mod.feature_importances_)
    
    print(f"{season} Accuracy: {(y_oos == prediction.round()).mean():.2f}")
    print(f"{season} AUC: {roc_auc_score(y_oos, prediction):.2f}")
    print(f"{season} Logloss: {log_loss(y_oos, prediction):.2f}")
    
    print()
    
predictions = np.concatenate(predictions)
feature_importances = np.array(feature_importances).mean(axis=0)
    
'Done'
# Out:
# 2003
# 2003 Accuracy: 0.67
# 2003 AUC: 0.79
# 2003 Logloss: 0.54
#
# 2004
# 2004 Accuracy: 0.73
# 2004 AUC: 0.79
# 2004 Logloss: 0.55
#
# 2005
# 2005 Accuracy: 0.72
# 2005 AUC: 0.83
# 2005 Logloss: 0.51
#
# 2006
# 2006 Accuracy: 0.72
# 2006 AUC: 0.80
# 2006 Logloss: 0.54
#
# 2007
# 2007 Accuracy: 0.77
# 2007 AUC: 0.88
# 2007 Logloss: 0.47
#
# 2008
# 2008 Accuracy: 0.78
# 2008 AUC: 0.86
# 2008 Logloss: 0.49
#
# 2009
# 2009 Accuracy: 0.75
# 2009 AUC: 0.84
# 2009 Logloss: 0.50
#
# 2010
# 2010 Accuracy: 0.70
# 2010 AUC: 0.77
# 2010 Logloss: 0.56
#
# 2011
# 2011 Accuracy: 0.63
# 2011 AUC: 0.71
# 2011 Logloss: 0.61
#
# 2012
# 2012 Accuracy: 0.72
# 2012 AUC: 0.79
# 2012 Logloss: 0.56
#
# 2013
# 2013 Accuracy: 0.69
# 2013 AUC: 0.73
# 2013 Logloss: 0.62
#
# 2014
# 2014 Accuracy: 0.69
# 2014 AUC: 0.75
# 2014 Logloss: 0.59
#
# 2015
# 2015 Accuracy: 0.75
# 2015 AUC: 0.82
# 2015 Logloss: 0.54
#
# 2016
# 2016 Accuracy: 0.73
# 2016 AUC: 0.78
# 2016 Logloss: 0.57
#
# 2017
# 2017 Accuracy: 0.70
# 2017 AUC: 0.79
# 2017 Logloss: 0.54
#
# 2018
# 2018 Accuracy: 0.69
# 2018 AUC: 0.75
# 2018 Logloss: 0.60
#
# 2019
# 2019 Accuracy: 0.73
# 2019 AUC: 0.87
# 2019 Logloss: 0.47
#
# 2021
# 2021 Accuracy: 0.72
# 2021 AUC: 0.73
# 2021 Logloss: 0.62
#
# 2022
# 2022 Accuracy: 0.63
# 2022 AUC: 0.71
# 2022 Logloss: 0.63
# 'Done'

# %%
(df['winner'] == predictions.round()).mean()
# Out:
# 0.7099358974358975

# %%
roc_auc_score(df['winner'], predictions)
# Out:
# 0.7866734210634451

# %%
log_loss(df['winner'], predictions)
# Out:
# 0.5526122326988022

# %%
features = pd.DataFrame({'feature': X_oos.columns, 
                         'importance': feature_importances}).sort_values(['importance'], 
                                                                         ascending=False, 
                                                                         ignore_index=True)

features
# Out:
#             feature  importance
# 0               SAG    0.341757
# 1               POM    0.190608
# 2               WLK    0.155012
# 3               MOR    0.124513
# 4          elo_diff    0.073744
# 5               COL    0.051031
# 6  ordinal_elo_diff    0.042027
# 7               RTH    0.019957
# 8               DOL    0.001352

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score, log_loss
# from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

predictions = []
feature_importances = []

for season in df['season'].unique():
    print(season)
    
    # s = MinMaxScaler()
    
    # split to in-sample and out-of-sample
    df_is = df.loc[~df['season'].isin([season]), :].reset_index(drop=True)
    df_oos = df.loc[df['season'].isin([season]), :].reset_index(drop=True)
    
    # train model
    eval_years = np.random.choice(df_is['season'].unique(), 5, replace=False)
    df_eval = df_is.loc[df_is['season'].isin(eval_years), :].reset_index(drop=True)
    df_train = df_is.loc[~df_is['season'].isin(eval_years), :].reset_index(drop=True)
    
    X_train = df_train.drop(columns=['winner', 'season'])
    # X_train = s.fit_transform(X_train)
    y_train = df_train['winner']
    
    X_eval = df_eval.drop(columns=['winner', 'season'])
    # X_eval = s.transform(X_eval)
    y_eval = df_eval['winner']    
    
    mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2000, 
                                    max_depth=1, eta=0.01)
    mod.fit(X_train, y_train, verbose=False, early_stopping_rounds=25, 
            eval_metric='logloss', eval_set=[(X_eval, y_eval)])
    
    
    # get out-of-sample predictions
    X_oos = df_oos.drop(columns=['winner', 'season'])
    # X_oos = s.transform(X_oos)
    y_oos = df_oos['winner']
    prediction = mod.predict_proba(X_oos)[:, 1]
    predictions.append(prediction)
    feature_importances.append(mod.feature_importances_)
    
    print(f"{season} Accuracy: {(y_oos == prediction.round()).mean():.2f}")
    print(f"{season} AUC: {roc_auc_score(y_oos, prediction):.2f}")
    print(f"{season} Logloss: {log_loss(y_oos, prediction):.2f}")
    
    print()
    
predictions = np.concatenate(predictions)
feature_importances = np.array(feature_importances).mean(axis=0)
    
'Done'
# Out:
# 2003
# 2003 Accuracy: 0.68
# 2003 AUC: 0.79
# 2003 Logloss: 0.54
#
# 2004
# 2004 Accuracy: 0.70
# 2004 AUC: 0.79
# 2004 Logloss: 0.55
#
# 2005
# 2005 Accuracy: 0.73
# 2005 AUC: 0.83
# 2005 Logloss: 0.51
#
# 2006
# 2006 Accuracy: 0.69
# 2006 AUC: 0.78
# 2006 Logloss: 0.56
#
# 2007
# 2007 Accuracy: 0.77
# 2007 AUC: 0.88
# 2007 Logloss: 0.48
#
# 2008
# 2008 Accuracy: 0.77
# 2008 AUC: 0.85
# 2008 Logloss: 0.49
#
# 2009
# 2009 Accuracy: 0.72
# 2009 AUC: 0.83
# 2009 Logloss: 0.50
#
# 2010
# 2010 Accuracy: 0.72
# 2010 AUC: 0.78
# 2010 Logloss: 0.55
#
# 2011
# 2011 Accuracy: 0.60
# 2011 AUC: 0.72
# 2011 Logloss: 0.61
#
# 2012
# 2012 Accuracy: 0.73
# 2012 AUC: 0.80
# 2012 Logloss: 0.57
#
# 2013
# 2013 Accuracy: 0.69
# 2013 AUC: 0.72
# 2013 Logloss: 0.61
#
# 2014
# 2014 Accuracy: 0.66
# 2014 AUC: 0.76
# 2014 Logloss: 0.57
#
# 2015
# 2015 Accuracy: 0.73
# 2015 AUC: 0.82
# 2015 Logloss: 0.52
#
# 2016
# 2016 Accuracy: 0.77
# 2016 AUC: 0.79
# 2016 Logloss: 0.57
#
# 2017
# 2017 Accuracy: 0.69
# 2017 AUC: 0.80
# 2017 Logloss: 0.53
#
# 2018
# 2018 Accuracy: 0.69
# 2018 AUC: 0.75
# 2018 Logloss: 0.60
#
# 2019
# 2019 Accuracy: 0.73
# 2019 AUC: 0.87
# 2019 Logloss: 0.47
#
# 2021
# 2021 Accuracy: 0.65
# 2021 AUC: 0.71
# 2021 Logloss: 0.66
#
# 2022
# 2022 Accuracy: 0.64
# 2022 AUC: 0.71
# 2022 Logloss: 0.63
# 'Done'

# %%
(df['winner'] == predictions.round()).mean()
# Out:
# 0.7027243589743589

# %%
roc_auc_score(df['winner'], predictions)
# Out:
# 0.7842374722633136

# %%
log_loss(df['winner'], predictions)
# Out:
# 0.5548198451467145

# %%
features = pd.DataFrame({'feature': X_oos.columns, 
                         'importance': feature_importances}).sort_values(['importance'], 
                                                                         ascending=False, 
                                                                         ignore_index=True)

features
# Out:
#             feature  importance
# 0               SAG    0.332524
# 1               POM    0.190600
# 2               WLK    0.149173
# 3               MOR    0.118657
# 4          elo_diff    0.070761
# 5               RTH    0.051625
# 6               COL    0.038766
# 7  ordinal_elo_diff    0.037177
# 8               DOL    0.010718

# %%
import seaborn as sns

sns.histplot(x=predictions)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df_acc = pd.read_pickle('../resources/data/preprocessed/tournament_games.pkl')[['winner', 'season', 'team0', 'team1']]

df_acc.sort_values(['season'], inplace=True, ignore_index=True)

df_acc['prediction'] = predictions

df_acc
# Out:
#       winner  season  team0  team1  prediction
# 0          0    2003   1421   1411    0.444305
# 1          1    2003   1400   1393    0.365938
# 2          1    2003   1242   1393    0.365938
# 3          1    2003   1447   1338    0.978825
# 4          1    2003   1335   1329    0.709477
# ...      ...     ...    ...    ...         ...
# 2491       0    2022   1181   1277    0.370973
# 2492       0    2022   1222   1228    0.391815
# 2493       0    2022   1235   1458    0.679291
# 2494       0    2022   1344   1350    0.223658
# 2495       1    2022   1314   1242    0.637754
#
# [2496 rows x 5 columns]

# %%
df_seeds = pd.read_csv('../resources/data/unprocessed/MNCAATourneySeeds.csv')

df_seeds['Seed'] = df_seeds['Seed'].str.extract('(\d+)').astype(int)

df_seeds
# Out:
#       Season  Seed  TeamID
# 0       1985     1    1207
# 1       1985     2    1210
# 2       1985     3    1228
# 3       1985     4    1260
# 4       1985     5    1374
# ...      ...   ...     ...
# 2485    2023    12    1433
# 2486    2023    13    1233
# 2487    2023    14    1213
# 2488    2023    15    1421
# 2489    2023    16    1224
#
# [2490 rows x 3 columns]

# %%
df_acc['seed_diff'] = (df_acc.merge(df_seeds, how='left', 
                                    left_on=['season', 'team1'], 
                                    right_on=['Season', 'TeamID'])['Seed'] - 
                       df_acc.merge(df_seeds, how='left', 
                                    left_on=['season', 'team0'], 
                                    right_on=['Season', 'TeamID'])['Seed'])

df_acc
# Out:
#       winner  season  team0  team1  prediction  seed_diff
# 0          0    2003   1421   1411    0.444305          0
# 1          1    2003   1400   1393    0.365938          2
# 2          1    2003   1242   1393    0.365938          1
# 3          1    2003   1447   1338    0.978825        -13
# 4          1    2003   1335   1329    0.709477         -5
# ...      ...     ...    ...    ...         ...        ...
# 2491       0    2022   1181   1277    0.370973          5
# 2492       0    2022   1222   1228    0.391815         -1
# 2493       0    2022   1235   1458    0.679291         -8
# 2494       0    2022   1344   1350    0.223658          8
# 2495       1    2022   1314   1242    0.637754         -7
#
# [2496 rows x 6 columns]

# %%
df_acc['correct'] = df_acc['winner'] == df_acc['prediction'].round()

df_acc
# Out:
#       winner  season  team0  team1  prediction  seed_diff  correct
# 0          0    2003   1421   1411    0.444305          0     True
# 1          1    2003   1400   1393    0.365938          2    False
# 2          1    2003   1242   1393    0.365938          1    False
# 3          1    2003   1447   1338    0.978825        -13     True
# 4          1    2003   1335   1329    0.709477         -5     True
# ...      ...     ...    ...    ...         ...        ...      ...
# 2491       0    2022   1181   1277    0.370973          5     True
# 2492       0    2022   1222   1228    0.391815         -1     True
# 2493       0    2022   1235   1458    0.679291         -8    False
# 2494       0    2022   1344   1350    0.223658          8     True
# 2495       1    2022   1314   1242    0.637754         -7     True
#
# [2496 rows x 7 columns]

# %%
df_acc_by_seed = df_acc.groupby(['seed_diff'])['correct'].mean().round(2)

df_acc_by_seed
# Out:
# seed_diff
# -15    0.99
# -13    0.92
# -12    0.80
# -11    0.89
# -10    0.57
# -9     0.79
# -8     0.76
# -7     0.67
# -6     0.55
# -5     0.62
# -4     0.70
# -3     0.65
# -2     0.68
# -1     0.52
#  0     0.58
#  1     0.51
#  2     0.68
#  3     0.66
#  4     0.70
#  5     0.62
#  6     0.55
#  7     0.67
#  8     0.76
#  9     0.79
#  10    0.57
#  11    0.89
#  12    0.80
#  13    0.92
#  15    0.99
# Name: correct, dtype: float64

# %%
import matplotlib.pyplot as plt

ax = sns.barplot(x=df_acc_by_seed, y=df_acc_by_seed.index, 
                 orient='h', color='#45B6FE')

ax.bar_label(ax.containers[0])

plt.xlabel('Accuracy %')
plt.ylabel('Seed Difference')
plt.title('Accuracy by Seed Difference')

plt.show()

# %%
eval_years = np.random.choice(df['season'].unique(), 5, replace=False)
# eval_years = [2009, 2010, 2014, 2007, 2017]
print(eval_years)
df_eval = df.loc[df['season'].isin(eval_years), :].reset_index(drop=True)
df_train = df.loc[~df['season'].isin(eval_years), :].reset_index(drop=True)

X_train = df_train.drop(columns=['winner', 'season'])
columns = X_train.columns
# X_train = s.fit_transform(X_train)
y_train = df_train['winner']

X_eval = df_eval.drop(columns=['winner', 'season'])
# X_eval = s.transform(X_eval)
y_eval = df_eval['winner']

best_mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2500, 
                             max_depth=1, eta=0.01)

best_mod.fit(X_train, y_train, verbose=True, early_stopping_rounds=50, 
             eval_metric='logloss', eval_set=[(X_eval, y_eval)])
# Out:
# [2006 2014 2008 2022 2016]
# [0]	validation_0-logloss:0.69144
# [1]	validation_0-logloss:0.68977
# [2]	validation_0-logloss:0.68814
# [3]	validation_0-logloss:0.68653
# [4]	validation_0-logloss:0.68496
# [5]	validation_0-logloss:0.68342
# [6]	validation_0-logloss:0.68191
# [7]	validation_0-logloss:0.68042
# [8]	validation_0-logloss:0.67897
# [9]	validation_0-logloss:0.67755
# [10]	validation_0-logloss:0.67615
# [11]	validation_0-logloss:0.67478
# [12]	validation_0-logloss:0.67344
# [13]	validation_0-logloss:0.67208
# [14]	validation_0-logloss:0.67073
# [15]	validation_0-logloss:0.66942
# [16]	validation_0-logloss:0.66804
# [17]	validation_0-logloss:0.66668
# [18]	validation_0-logloss:0.66543
# [19]	validation_0-logloss:0.66412
# [20]	validation_0-logloss:0.66283
# [21]	validation_0-logloss:0.66164
# [22]	validation_0-logloss:0.66047
# [23]	validation_0-logloss:0.65924
# [24]	validation_0-logloss:0.65803
# [25]	validation_0-logloss:0.65692
# [26]	validation_0-logloss:0.65575
# [27]	validation_0-logloss:0.65459
# [28]	validation_0-logloss:0.65365
# [29]	validation_0-logloss:0.65272
# [30]	validation_0-logloss:0.65162
# [31]	validation_0-logloss:0.65073
# [32]	validation_0-logloss:0.64985
# [33]	validation_0-logloss:0.64879
# [34]	validation_0-logloss:0.64773
# [35]	validation_0-logloss:0.64689
# [36]	validation_0-logloss:0.64586
# [37]	validation_0-logloss:0.64504
# [38]	validation_0-logloss:0.64404
# [39]	validation_0-logloss:0.64326
# [40]	validation_0-logloss:0.64249
# [41]	validation_0-logloss:0.64152
# [42]	validation_0-logloss:0.64059
# [43]	validation_0-logloss:0.63986
# [44]	validation_0-logloss:0.63914
# [45]	validation_0-logloss:0.63822
# [46]	validation_0-logloss:0.63733
# [47]	validation_0-logloss:0.63646
# [48]	validation_0-logloss:0.63578
# [49]	validation_0-logloss:0.63512
# [50]	validation_0-logloss:0.63427
# [51]	validation_0-logloss:0.63365
# [52]	validation_0-logloss:0.63303
# [53]	validation_0-logloss:0.63221
# [54]	validation_0-logloss:0.63160
# [55]	validation_0-logloss:0.63086
# [56]	validation_0-logloss:0.63012
# [57]	validation_0-logloss:0.62955
# [58]	validation_0-logloss:0.62899
# [59]	validation_0-logloss:0.62828
# [60]	validation_0-logloss:0.62758
# [61]	validation_0-logloss:0.62702
# [62]	validation_0-logloss:0.62633
# [63]	validation_0-logloss:0.62565
# [64]	validation_0-logloss:0.62514
# [65]	validation_0-logloss:0.62462
# [66]	validation_0-logloss:0.62397
# [67]	validation_0-logloss:0.62332
# [68]	validation_0-logloss:0.62263
# [69]	validation_0-logloss:0.62199
# [70]	validation_0-logloss:0.62135
# [71]	validation_0-logloss:0.62072
# [72]	validation_0-logloss:0.62010
# [73]	validation_0-logloss:0.61964
# [74]	validation_0-logloss:0.61919
# [75]	validation_0-logloss:0.61857
# [76]	validation_0-logloss:0.61798
# [77]	validation_0-logloss:0.61739
# [78]	validation_0-logloss:0.61681
# [79]	validation_0-logloss:0.61623
# [80]	validation_0-logloss:0.61581
# [81]	validation_0-logloss:0.61540
# [82]	validation_0-logloss:0.61484
# [83]	validation_0-logloss:0.61429
# [84]	validation_0-logloss:0.61374
# [85]	validation_0-logloss:0.61320
# [86]	validation_0-logloss:0.61267
# [87]	validation_0-logloss:0.61229
# [88]	validation_0-logloss:0.61191
# [89]	validation_0-logloss:0.61140
# [90]	validation_0-logloss:0.61089
# [91]	validation_0-logloss:0.61038
# [92]	validation_0-logloss:0.60988
# [93]	validation_0-logloss:0.60951
# [94]	validation_0-logloss:0.60903
# [95]	validation_0-logloss:0.60854
# [96]	validation_0-logloss:0.60820
# [97]	validation_0-logloss:0.60787
# [98]	validation_0-logloss:0.60741
# [99]	validation_0-logloss:0.60695
# [100]	validation_0-logloss:0.60661
# [101]	validation_0-logloss:0.60616
# [102]	validation_0-logloss:0.60571
# [103]	validation_0-logloss:0.60526
# [104]	validation_0-logloss:0.60482
# [105]	validation_0-logloss:0.60439
# [106]	validation_0-logloss:0.60410
# [107]	validation_0-logloss:0.60381
# [108]	validation_0-logloss:0.60339
# [109]	validation_0-logloss:0.60298
# [110]	validation_0-logloss:0.60257
# [111]	validation_0-logloss:0.60215
# [112]	validation_0-logloss:0.60176
# [113]	validation_0-logloss:0.60136
# [114]	validation_0-logloss:0.60108
# [115]	validation_0-logloss:0.60068
# [116]	validation_0-logloss:0.60029
# [117]	validation_0-logloss:0.59991
# [118]	validation_0-logloss:0.59954
# [119]	validation_0-logloss:0.59916
# [120]	validation_0-logloss:0.59878
# [121]	validation_0-logloss:0.59852
# [122]	validation_0-logloss:0.59816
# [123]	validation_0-logloss:0.59780
# [124]	validation_0-logloss:0.59744
# [125]	validation_0-logloss:0.59708
# [126]	validation_0-logloss:0.59674
# [127]	validation_0-logloss:0.59639
# [128]	validation_0-logloss:0.59604
# [129]	validation_0-logloss:0.59570
# [130]	validation_0-logloss:0.59537
# [131]	validation_0-logloss:0.59503
# [132]	validation_0-logloss:0.59469
# [133]	validation_0-logloss:0.59437
# [134]	validation_0-logloss:0.59415
# [135]	validation_0-logloss:0.59383
# [136]	validation_0-logloss:0.59350
# [137]	validation_0-logloss:0.59319
# [138]	validation_0-logloss:0.59288
# [139]	validation_0-logloss:0.59257
# [140]	validation_0-logloss:0.59226
# [141]	validation_0-logloss:0.59196
# [142]	validation_0-logloss:0.59167
# [143]	validation_0-logloss:0.59148
# [144]	validation_0-logloss:0.59118
# [145]	validation_0-logloss:0.59088
# [146]	validation_0-logloss:0.59060
# [147]	validation_0-logloss:0.59032
# [148]	validation_0-logloss:0.59003
# [149]	validation_0-logloss:0.58974
# [150]	validation_0-logloss:0.58947
# [151]	validation_0-logloss:0.58920
# [152]	validation_0-logloss:0.58894
# [153]	validation_0-logloss:0.58869
# [154]	validation_0-logloss:0.58841
# [155]	validation_0-logloss:0.58816
# [156]	validation_0-logloss:0.58791
# [157]	validation_0-logloss:0.58765
# [158]	validation_0-logloss:0.58739
# [159]	validation_0-logloss:0.58713
# [160]	validation_0-logloss:0.58689
# [161]	validation_0-logloss:0.58664
# [162]	validation_0-logloss:0.58639
# [163]	validation_0-logloss:0.58616
# [164]	validation_0-logloss:0.58591
# [165]	validation_0-logloss:0.58567
# [166]	validation_0-logloss:0.58543
# [167]	validation_0-logloss:0.58520
# [168]	validation_0-logloss:0.58497
# [169]	validation_0-logloss:0.58475
# [170]	validation_0-logloss:0.58452
# [171]	validation_0-logloss:0.58439
# [172]	validation_0-logloss:0.58417
# [173]	validation_0-logloss:0.58394
# [174]	validation_0-logloss:0.58373
# [175]	validation_0-logloss:0.58352
# [176]	validation_0-logloss:0.58339
# [177]	validation_0-logloss:0.58318
# [178]	validation_0-logloss:0.58296
# [179]	validation_0-logloss:0.58276
# [180]	validation_0-logloss:0.58256
# [181]	validation_0-logloss:0.58235
# [182]	validation_0-logloss:0.58214
# [183]	validation_0-logloss:0.58195
# [184]	validation_0-logloss:0.58175
# [185]	validation_0-logloss:0.58155
# [186]	validation_0-logloss:0.58135
# [187]	validation_0-logloss:0.58113
# [188]	validation_0-logloss:0.58092
# [189]	validation_0-logloss:0.58072
# [190]	validation_0-logloss:0.58053
# [191]	validation_0-logloss:0.58032
# [192]	validation_0-logloss:0.58011
# [193]	validation_0-logloss:0.58001
# [194]	validation_0-logloss:0.57981
# [195]	validation_0-logloss:0.57961
# [196]	validation_0-logloss:0.57942
# [197]	validation_0-logloss:0.57924
# [198]	validation_0-logloss:0.57907
# [199]	validation_0-logloss:0.57887
# [200]	validation_0-logloss:0.57867
# [201]	validation_0-logloss:0.57850
# [202]	validation_0-logloss:0.57832
# [203]	validation_0-logloss:0.57815
# [204]	validation_0-logloss:0.57797
# [205]	validation_0-logloss:0.57778
# [206]	validation_0-logloss:0.57770
# [207]	validation_0-logloss:0.57753
# [208]	validation_0-logloss:0.57737
# [209]	validation_0-logloss:0.57719
# [210]	validation_0-logloss:0.57702
# [211]	validation_0-logloss:0.57686
# [212]	validation_0-logloss:0.57669
# [213]	validation_0-logloss:0.57652
# [214]	validation_0-logloss:0.57636
# [215]	validation_0-logloss:0.57622
# [216]	validation_0-logloss:0.57605
# [217]	validation_0-logloss:0.57590
# [218]	validation_0-logloss:0.57575
# [219]	validation_0-logloss:0.57558
# [220]	validation_0-logloss:0.57544
# [221]	validation_0-logloss:0.57529
# [222]	validation_0-logloss:0.57513
# [223]	validation_0-logloss:0.57498
# [224]	validation_0-logloss:0.57484
# [225]	validation_0-logloss:0.57478
# [226]	validation_0-logloss:0.57463
# [227]	validation_0-logloss:0.57447
# [228]	validation_0-logloss:0.57434
# [229]	validation_0-logloss:0.57420
# [230]	validation_0-logloss:0.57405
# [231]	validation_0-logloss:0.57390
# [232]	validation_0-logloss:0.57385
# [233]	validation_0-logloss:0.57371
# [234]	validation_0-logloss:0.57356
# [235]	validation_0-logloss:0.57343
# [236]	validation_0-logloss:0.57330
# [237]	validation_0-logloss:0.57316
# [238]	validation_0-logloss:0.57302
# [239]	validation_0-logloss:0.57290
# [240]	validation_0-logloss:0.57277
# [241]	validation_0-logloss:0.57263
# [242]	validation_0-logloss:0.57250
# [243]	validation_0-logloss:0.57246
# [244]	validation_0-logloss:0.57232
# [245]	validation_0-logloss:0.57219
# [246]	validation_0-logloss:0.57207
# [247]	validation_0-logloss:0.57195
# [248]	validation_0-logloss:0.57183
# [249]	validation_0-logloss:0.57170
# [250]	validation_0-logloss:0.57159
# [251]	validation_0-logloss:0.57147
# [252]	validation_0-logloss:0.57136
# [253]	validation_0-logloss:0.57124
# [254]	validation_0-logloss:0.57111
# [255]	validation_0-logloss:0.57108
# [256]	validation_0-logloss:0.57096
# [257]	validation_0-logloss:0.57084
# [258]	validation_0-logloss:0.57073
# [259]	validation_0-logloss:0.57063
# [260]	validation_0-logloss:0.57051
# [261]	validation_0-logloss:0.57039
# [262]	validation_0-logloss:0.57029
# [263]	validation_0-logloss:0.57019
# [264]	validation_0-logloss:0.57008
# [265]	validation_0-logloss:0.56996
# [266]	validation_0-logloss:0.56986
# [267]	validation_0-logloss:0.56976
# [268]	validation_0-logloss:0.56965
# [269]	validation_0-logloss:0.56963
# [270]	validation_0-logloss:0.56952
# [271]	validation_0-logloss:0.56942
# [272]	validation_0-logloss:0.56933
# [273]	validation_0-logloss:0.56922
# [274]	validation_0-logloss:0.56912
# [275]	validation_0-logloss:0.56903
# [276]	validation_0-logloss:0.56894
# [277]	validation_0-logloss:0.56885
# [278]	validation_0-logloss:0.56875
# [279]	validation_0-logloss:0.56865
# [280]	validation_0-logloss:0.56863
# [281]	validation_0-logloss:0.56856
# [282]	validation_0-logloss:0.56849
# [283]	validation_0-logloss:0.56839
# [284]	validation_0-logloss:0.56829
# [285]	validation_0-logloss:0.56822
# [286]	validation_0-logloss:0.56815
# [287]	validation_0-logloss:0.56806
# [288]	validation_0-logloss:0.56799
# [289]	validation_0-logloss:0.56793
# [290]	validation_0-logloss:0.56783
# [291]	validation_0-logloss:0.56782
# [292]	validation_0-logloss:0.56774
# [293]	validation_0-logloss:0.56768
# [294]	validation_0-logloss:0.56759
# [295]	validation_0-logloss:0.56750
# [296]	validation_0-logloss:0.56744
# [297]	validation_0-logloss:0.56736
# [298]	validation_0-logloss:0.56735
# [299]	validation_0-logloss:0.56729
# [300]	validation_0-logloss:0.56723
# [301]	validation_0-logloss:0.56715
# [302]	validation_0-logloss:0.56706
# [303]	validation_0-logloss:0.56700
# [304]	validation_0-logloss:0.56695
# [305]	validation_0-logloss:0.56686
# [306]	validation_0-logloss:0.56678
# [307]	validation_0-logloss:0.56678
# [308]	validation_0-logloss:0.56672
# [309]	validation_0-logloss:0.56667
# [310]	validation_0-logloss:0.56667
# [311]	validation_0-logloss:0.56659
# [312]	validation_0-logloss:0.56651
# [313]	validation_0-logloss:0.56646
# [314]	validation_0-logloss:0.56641
# [315]	validation_0-logloss:0.56633
# [316]	validation_0-logloss:0.56628
# [317]	validation_0-logloss:0.56623
# [318]	validation_0-logloss:0.56615
# [319]	validation_0-logloss:0.56609
# [320]	validation_0-logloss:0.56604
# [321]	validation_0-logloss:0.56599
# [322]	validation_0-logloss:0.56592
# [323]	validation_0-logloss:0.56588
# [324]	validation_0-logloss:0.56581
# [325]	validation_0-logloss:0.56574
# [326]	validation_0-logloss:0.56567
# [327]	validation_0-logloss:0.56563
# [328]	validation_0-logloss:0.56559
# [329]	validation_0-logloss:0.56559
# [330]	validation_0-logloss:0.56552
# [331]	validation_0-logloss:0.56545
# [332]	validation_0-logloss:0.56541
# [333]	validation_0-logloss:0.56537
# [334]	validation_0-logloss:0.56537
# [335]	validation_0-logloss:0.56534
# [336]	validation_0-logloss:0.56529
# [337]	validation_0-logloss:0.56523
# [338]	validation_0-logloss:0.56517
# [339]	validation_0-logloss:0.56513
# [340]	validation_0-logloss:0.56509
# [341]	validation_0-logloss:0.56510
# [342]	validation_0-logloss:0.56503
# [343]	validation_0-logloss:0.56497
# [344]	validation_0-logloss:0.56491
# [345]	validation_0-logloss:0.56485
# [346]	validation_0-logloss:0.56485
# [347]	validation_0-logloss:0.56479
# [348]	validation_0-logloss:0.56473
# [349]	validation_0-logloss:0.56468
# [350]	validation_0-logloss:0.56462
# [351]	validation_0-logloss:0.56456
# [352]	validation_0-logloss:0.56450
# [353]	validation_0-logloss:0.56444
# [354]	validation_0-logloss:0.56440
# [355]	validation_0-logloss:0.56434
# [356]	validation_0-logloss:0.56428
# [357]	validation_0-logloss:0.56422
# [358]	validation_0-logloss:0.56417
# [359]	validation_0-logloss:0.56411
# [360]	validation_0-logloss:0.56405
# [361]	validation_0-logloss:0.56407
# [362]	validation_0-logloss:0.56401
# [363]	validation_0-logloss:0.56395
# [364]	validation_0-logloss:0.56397
# [365]	validation_0-logloss:0.56391
# [366]	validation_0-logloss:0.56386
# [367]	validation_0-logloss:0.56382
# [368]	validation_0-logloss:0.56377
# [369]	validation_0-logloss:0.56372
# [370]	validation_0-logloss:0.56366
# [371]	validation_0-logloss:0.56361
# [372]	validation_0-logloss:0.56357
# [373]	validation_0-logloss:0.56352
# [374]	validation_0-logloss:0.56347
# [375]	validation_0-logloss:0.56344
# [376]	validation_0-logloss:0.56337
# [377]	validation_0-logloss:0.56332
# [378]	validation_0-logloss:0.56327
# [379]	validation_0-logloss:0.56329
# [380]	validation_0-logloss:0.56324
# [381]	validation_0-logloss:0.56319
# [382]	validation_0-logloss:0.56315
# [383]	validation_0-logloss:0.56309
# [384]	validation_0-logloss:0.56310
# [385]	validation_0-logloss:0.56306
# [386]	validation_0-logloss:0.56301
# [387]	validation_0-logloss:0.56297
# [388]	validation_0-logloss:0.56292
# [389]	validation_0-logloss:0.56288
# [390]	validation_0-logloss:0.56283
# [391]	validation_0-logloss:0.56279
# [392]	validation_0-logloss:0.56275
# [393]	validation_0-logloss:0.56270
# [394]	validation_0-logloss:0.56265
# [395]	validation_0-logloss:0.56261
# [396]	validation_0-logloss:0.56256
# [397]	validation_0-logloss:0.56253
# [398]	validation_0-logloss:0.56248
# [399]	validation_0-logloss:0.56244
# [400]	validation_0-logloss:0.56246
# [401]	validation_0-logloss:0.56242
# [402]	validation_0-logloss:0.56238
# [403]	validation_0-logloss:0.56234
# [404]	validation_0-logloss:0.56230
# [405]	validation_0-logloss:0.56226
# [406]	validation_0-logloss:0.56222
# [407]	validation_0-logloss:0.56224
# [408]	validation_0-logloss:0.56221
# [409]	validation_0-logloss:0.56217
# [410]	validation_0-logloss:0.56212
# [411]	validation_0-logloss:0.56207
# [412]	validation_0-logloss:0.56203
# [413]	validation_0-logloss:0.56200
# [414]	validation_0-logloss:0.56196
# [415]	validation_0-logloss:0.56191
# [416]	validation_0-logloss:0.56193
# [417]	validation_0-logloss:0.56188
# [418]	validation_0-logloss:0.56184
# [419]	validation_0-logloss:0.56180
# [420]	validation_0-logloss:0.56176
# [421]	validation_0-logloss:0.56172
# [422]	validation_0-logloss:0.56167
# [423]	validation_0-logloss:0.56169
# [424]	validation_0-logloss:0.56165
# [425]	validation_0-logloss:0.56160
# [426]	validation_0-logloss:0.56156
# [427]	validation_0-logloss:0.56151
# [428]	validation_0-logloss:0.56147
# [429]	validation_0-logloss:0.56143
# [430]	validation_0-logloss:0.56145
# [431]	validation_0-logloss:0.56141
# [432]	validation_0-logloss:0.56138
# [433]	validation_0-logloss:0.56134
# [434]	validation_0-logloss:0.56129
# [435]	validation_0-logloss:0.56127
# [436]	validation_0-logloss:0.56122
# [437]	validation_0-logloss:0.56118
# [438]	validation_0-logloss:0.56120
# [439]	validation_0-logloss:0.56117
# [440]	validation_0-logloss:0.56113
# [441]	validation_0-logloss:0.56109
# [442]	validation_0-logloss:0.56105
# [443]	validation_0-logloss:0.56108
# [444]	validation_0-logloss:0.56104
# [445]	validation_0-logloss:0.56100
# [446]	validation_0-logloss:0.56097
# [447]	validation_0-logloss:0.56093
# [448]	validation_0-logloss:0.56089
# [449]	validation_0-logloss:0.56085
# [450]	validation_0-logloss:0.56082
# [451]	validation_0-logloss:0.56079
# [452]	validation_0-logloss:0.56077
# [453]	validation_0-logloss:0.56073
# [454]	validation_0-logloss:0.56069
# [455]	validation_0-logloss:0.56065
# [456]	validation_0-logloss:0.56061
# [457]	validation_0-logloss:0.56057
# [458]	validation_0-logloss:0.56054
# [459]	validation_0-logloss:0.56056
# [460]	validation_0-logloss:0.56052
# [461]	validation_0-logloss:0.56048
# [462]	validation_0-logloss:0.56046
# [463]	validation_0-logloss:0.56043
# [464]	validation_0-logloss:0.56039
# [465]	validation_0-logloss:0.56035
# [466]	validation_0-logloss:0.56038
# [467]	validation_0-logloss:0.56034
# [468]	validation_0-logloss:0.56030
# [469]	validation_0-logloss:0.56028
# [470]	validation_0-logloss:0.56027
# [471]	validation_0-logloss:0.56023
# [472]	validation_0-logloss:0.56019
# [473]	validation_0-logloss:0.56017
# [474]	validation_0-logloss:0.56014
# [475]	validation_0-logloss:0.56017
# [476]	validation_0-logloss:0.56013
# [477]	validation_0-logloss:0.56010
# [478]	validation_0-logloss:0.56008
# [479]	validation_0-logloss:0.56005
# [480]	validation_0-logloss:0.56001
# [481]	validation_0-logloss:0.56000
# [482]	validation_0-logloss:0.55997
# [483]	validation_0-logloss:0.55995
# [484]	validation_0-logloss:0.55991
# [485]	validation_0-logloss:0.55988
# [486]	validation_0-logloss:0.55986
# [487]	validation_0-logloss:0.55983
# [488]	validation_0-logloss:0.55979
# [489]	validation_0-logloss:0.55978
# [490]	validation_0-logloss:0.55974
# [491]	validation_0-logloss:0.55971
# [492]	validation_0-logloss:0.55973
# [493]	validation_0-logloss:0.55971
# [494]	validation_0-logloss:0.55969
# [495]	validation_0-logloss:0.55966
# [496]	validation_0-logloss:0.55968
# [497]	validation_0-logloss:0.55965
# [498]	validation_0-logloss:0.55962
# [499]	validation_0-logloss:0.55958
# [500]	validation_0-logloss:0.55955
# [501]	validation_0-logloss:0.55958
# [502]	validation_0-logloss:0.55955
# [503]	validation_0-logloss:0.55951
# [504]	validation_0-logloss:0.55949
# [505]	validation_0-logloss:0.55947
# [506]	validation_0-logloss:0.55944
# [507]	validation_0-logloss:0.55941
# [508]	validation_0-logloss:0.55939
# [509]	validation_0-logloss:0.55938
# [510]	validation_0-logloss:0.55935
# [511]	validation_0-logloss:0.55932
# [512]	validation_0-logloss:0.55929
# [513]	validation_0-logloss:0.55932
# [514]	validation_0-logloss:0.55929
# [515]	validation_0-logloss:0.55925
# [516]	validation_0-logloss:0.55924
# [517]	validation_0-logloss:0.55922
# [518]	validation_0-logloss:0.55919
# [519]	validation_0-logloss:0.55916
# [520]	validation_0-logloss:0.55915
# [521]	validation_0-logloss:0.55914
# [522]	validation_0-logloss:0.55911
# [523]	validation_0-logloss:0.55908
# [524]	validation_0-logloss:0.55911
# [525]	validation_0-logloss:0.55909
# [526]	validation_0-logloss:0.55907
# [527]	validation_0-logloss:0.55904
# [528]	validation_0-logloss:0.55901
# [529]	validation_0-logloss:0.55904
# [530]	validation_0-logloss:0.55901
# [531]	validation_0-logloss:0.55898
# [532]	validation_0-logloss:0.55897
# [533]	validation_0-logloss:0.55894
# [534]	validation_0-logloss:0.55892
# [535]	validation_0-logloss:0.55889
# [536]	validation_0-logloss:0.55888
# [537]	validation_0-logloss:0.55886
# [538]	validation_0-logloss:0.55883
# [539]	validation_0-logloss:0.55880
# [540]	validation_0-logloss:0.55883
# [541]	validation_0-logloss:0.55882
# [542]	validation_0-logloss:0.55879
# [543]	validation_0-logloss:0.55876
# [544]	validation_0-logloss:0.55875
# [545]	validation_0-logloss:0.55872
# [546]	validation_0-logloss:0.55875
# [547]	validation_0-logloss:0.55872
# [548]	validation_0-logloss:0.55870
# [549]	validation_0-logloss:0.55868
# [550]	validation_0-logloss:0.55865
# [551]	validation_0-logloss:0.55863
# [552]	validation_0-logloss:0.55866
# [553]	validation_0-logloss:0.55863
# [554]	validation_0-logloss:0.55860
# [555]	validation_0-logloss:0.55859
# [556]	validation_0-logloss:0.55858
# [557]	validation_0-logloss:0.55855
# [558]	validation_0-logloss:0.55853
# [559]	validation_0-logloss:0.55851
# [560]	validation_0-logloss:0.55850
# [561]	validation_0-logloss:0.55849
# [562]	validation_0-logloss:0.55846
# [563]	validation_0-logloss:0.55844
# [564]	validation_0-logloss:0.55842
# [565]	validation_0-logloss:0.55845
# [566]	validation_0-logloss:0.55843
# [567]	validation_0-logloss:0.55840
# [568]	validation_0-logloss:0.55839
# [569]	validation_0-logloss:0.55838
# [570]	validation_0-logloss:0.55836
# [571]	validation_0-logloss:0.55833
# [572]	validation_0-logloss:0.55832
# [573]	validation_0-logloss:0.55831
# [574]	validation_0-logloss:0.55829
# [575]	validation_0-logloss:0.55827
# [576]	validation_0-logloss:0.55829
# [577]	validation_0-logloss:0.55827
# [578]	validation_0-logloss:0.55824
# [579]	validation_0-logloss:0.55823
# [580]	validation_0-logloss:0.55822
# [581]	validation_0-logloss:0.55825
# [582]	validation_0-logloss:0.55822
# [583]	validation_0-logloss:0.55820
# [584]	validation_0-logloss:0.55823
# [585]	validation_0-logloss:0.55820
# [586]	validation_0-logloss:0.55818
# [587]	validation_0-logloss:0.55816
# [588]	validation_0-logloss:0.55815
# [589]	validation_0-logloss:0.55812
# [590]	validation_0-logloss:0.55810
# [591]	validation_0-logloss:0.55813
# [592]	validation_0-logloss:0.55812
# [593]	validation_0-logloss:0.55810
# [594]	validation_0-logloss:0.55808
# [595]	validation_0-logloss:0.55806
# [596]	validation_0-logloss:0.55806
# [597]	validation_0-logloss:0.55805
# [598]	validation_0-logloss:0.55803
# [599]	validation_0-logloss:0.55801
# [600]	validation_0-logloss:0.55800
# [601]	validation_0-logloss:0.55798
# [602]	validation_0-logloss:0.55796
# [603]	validation_0-logloss:0.55796
# [604]	validation_0-logloss:0.55795
# [605]	validation_0-logloss:0.55793
# [606]	validation_0-logloss:0.55791
# [607]	validation_0-logloss:0.55789
# [608]	validation_0-logloss:0.55792
# [609]	validation_0-logloss:0.55790
# [610]	validation_0-logloss:0.55788
# [611]	validation_0-logloss:0.55787
# [612]	validation_0-logloss:0.55785
# [613]	validation_0-logloss:0.55783
# [614]	validation_0-logloss:0.55783
# [615]	validation_0-logloss:0.55782
# [616]	validation_0-logloss:0.55781
# [617]	validation_0-logloss:0.55784
# [618]	validation_0-logloss:0.55782
# [619]	validation_0-logloss:0.55780
# [620]	validation_0-logloss:0.55777
# [621]	validation_0-logloss:0.55776
# [622]	validation_0-logloss:0.55775
# [623]	validation_0-logloss:0.55773
# [624]	validation_0-logloss:0.55771
# [625]	validation_0-logloss:0.55770
# [626]	validation_0-logloss:0.55770
# [627]	validation_0-logloss:0.55768
# [628]	validation_0-logloss:0.55766
# [629]	validation_0-logloss:0.55764
# [630]	validation_0-logloss:0.55763
# [631]	validation_0-logloss:0.55760
# [632]	validation_0-logloss:0.55763
# [633]	validation_0-logloss:0.55761
# [634]	validation_0-logloss:0.55759
# [635]	validation_0-logloss:0.55758
# [636]	validation_0-logloss:0.55760
# [637]	validation_0-logloss:0.55758
# [638]	validation_0-logloss:0.55757
# [639]	validation_0-logloss:0.55754
# [640]	validation_0-logloss:0.55753
# [641]	validation_0-logloss:0.55753
# [642]	validation_0-logloss:0.55751
# [643]	validation_0-logloss:0.55750
# [644]	validation_0-logloss:0.55748
# [645]	validation_0-logloss:0.55751
# [646]	validation_0-logloss:0.55749
# [647]	validation_0-logloss:0.55748
# [648]	validation_0-logloss:0.55746
# [649]	validation_0-logloss:0.55748
# [650]	validation_0-logloss:0.55747
# [651]	validation_0-logloss:0.55746
# [652]	validation_0-logloss:0.55744
# [653]	validation_0-logloss:0.55743
# [654]	validation_0-logloss:0.55742
# [655]	validation_0-logloss:0.55741
# [656]	validation_0-logloss:0.55739
# [657]	validation_0-logloss:0.55738
# [658]	validation_0-logloss:0.55736
# [659]	validation_0-logloss:0.55735
# [660]	validation_0-logloss:0.55734
# [661]	validation_0-logloss:0.55732
# [662]	validation_0-logloss:0.55731
# [663]	validation_0-logloss:0.55734
# [664]	validation_0-logloss:0.55732
# [665]	validation_0-logloss:0.55731
# [666]	validation_0-logloss:0.55730
# [667]	validation_0-logloss:0.55730
# [668]	validation_0-logloss:0.55729
# [669]	validation_0-logloss:0.55727
# [670]	validation_0-logloss:0.55726
# [671]	validation_0-logloss:0.55725
# [672]	validation_0-logloss:0.55724
# [673]	validation_0-logloss:0.55723
# [674]	validation_0-logloss:0.55722
# [675]	validation_0-logloss:0.55724
# [676]	validation_0-logloss:0.55723
# [677]	validation_0-logloss:0.55722
# [678]	validation_0-logloss:0.55720
# [679]	validation_0-logloss:0.55719
# [680]	validation_0-logloss:0.55718
# [681]	validation_0-logloss:0.55717
# [682]	validation_0-logloss:0.55716
# [683]	validation_0-logloss:0.55715
# [684]	validation_0-logloss:0.55714
# [685]	validation_0-logloss:0.55713
# [686]	validation_0-logloss:0.55713
# [687]	validation_0-logloss:0.55712
# [688]	validation_0-logloss:0.55711
# [689]	validation_0-logloss:0.55710
# [690]	validation_0-logloss:0.55708
# [691]	validation_0-logloss:0.55707
# [692]	validation_0-logloss:0.55706
# [693]	validation_0-logloss:0.55709
# [694]	validation_0-logloss:0.55707
# [695]	validation_0-logloss:0.55706
# [696]	validation_0-logloss:0.55705
# [697]	validation_0-logloss:0.55703
# [698]	validation_0-logloss:0.55706
# [699]	validation_0-logloss:0.55705
# [700]	validation_0-logloss:0.55703
# [701]	validation_0-logloss:0.55703
# [702]	validation_0-logloss:0.55702
# [703]	validation_0-logloss:0.55701
# [704]	validation_0-logloss:0.55701
# [705]	validation_0-logloss:0.55700
# [706]	validation_0-logloss:0.55699
# [707]	validation_0-logloss:0.55701
# [708]	validation_0-logloss:0.55700
# [709]	validation_0-logloss:0.55699
# [710]	validation_0-logloss:0.55697
# [711]	validation_0-logloss:0.55696
# [712]	validation_0-logloss:0.55695
# [713]	validation_0-logloss:0.55694
# [714]	validation_0-logloss:0.55696
# [715]	validation_0-logloss:0.55695
# [716]	validation_0-logloss:0.55694
# [717]	validation_0-logloss:0.55693
# [718]	validation_0-logloss:0.55692
# [719]	validation_0-logloss:0.55691
# [720]	validation_0-logloss:0.55690
# [721]	validation_0-logloss:0.55690
# [722]	validation_0-logloss:0.55689
# [723]	validation_0-logloss:0.55688
# [724]	validation_0-logloss:0.55690
# [725]	validation_0-logloss:0.55689
# [726]	validation_0-logloss:0.55688
# [727]	validation_0-logloss:0.55687
# [728]	validation_0-logloss:0.55685
# [729]	validation_0-logloss:0.55685
# [730]	validation_0-logloss:0.55684
# [731]	validation_0-logloss:0.55683
# [732]	validation_0-logloss:0.55682
# [733]	validation_0-logloss:0.55681
# [734]	validation_0-logloss:0.55681
# [735]	validation_0-logloss:0.55681
# [736]	validation_0-logloss:0.55680
# [737]	validation_0-logloss:0.55678
# [738]	validation_0-logloss:0.55678
# [739]	validation_0-logloss:0.55678
# [740]	validation_0-logloss:0.55676
# [741]	validation_0-logloss:0.55679
# [742]	validation_0-logloss:0.55678
# [743]	validation_0-logloss:0.55676
# [744]	validation_0-logloss:0.55675
# [745]	validation_0-logloss:0.55674
# [746]	validation_0-logloss:0.55673
# [747]	validation_0-logloss:0.55673
# [748]	validation_0-logloss:0.55671
# [749]	validation_0-logloss:0.55671
# [750]	validation_0-logloss:0.55670
# [751]	validation_0-logloss:0.55669
# [752]	validation_0-logloss:0.55671
# [753]	validation_0-logloss:0.55671
# [754]	validation_0-logloss:0.55670
# [755]	validation_0-logloss:0.55669
# [756]	validation_0-logloss:0.55668
# [757]	validation_0-logloss:0.55667
# [758]	validation_0-logloss:0.55667
# [759]	validation_0-logloss:0.55666
# [760]	validation_0-logloss:0.55666
# [761]	validation_0-logloss:0.55665
# [762]	validation_0-logloss:0.55664
# [763]	validation_0-logloss:0.55663
# [764]	validation_0-logloss:0.55663
# [765]	validation_0-logloss:0.55662
# [766]	validation_0-logloss:0.55661
# [767]	validation_0-logloss:0.55663
# [768]	validation_0-logloss:0.55662
# [769]	validation_0-logloss:0.55661
# [770]	validation_0-logloss:0.55661
# [771]	validation_0-logloss:0.55660
# [772]	validation_0-logloss:0.55659
# [773]	validation_0-logloss:0.55658
# [774]	validation_0-logloss:0.55657
# [775]	validation_0-logloss:0.55656
# [776]	validation_0-logloss:0.55659
# [777]	validation_0-logloss:0.55658
# [778]	validation_0-logloss:0.55657
# [779]	validation_0-logloss:0.55659
# [780]	validation_0-logloss:0.55658
# [781]	validation_0-logloss:0.55657
# [782]	validation_0-logloss:0.55656
# [783]	validation_0-logloss:0.55655
# [784]	validation_0-logloss:0.55655
# [785]	validation_0-logloss:0.55654
# [786]	validation_0-logloss:0.55654
# [787]	validation_0-logloss:0.55654
# [788]	validation_0-logloss:0.55653
# [789]	validation_0-logloss:0.55652
# [790]	validation_0-logloss:0.55654
# [791]	validation_0-logloss:0.55654
# [792]	validation_0-logloss:0.55653
# [793]	validation_0-logloss:0.55652
# [794]	validation_0-logloss:0.55650
# [795]	validation_0-logloss:0.55650
# [796]	validation_0-logloss:0.55649
# [797]	validation_0-logloss:0.55649
# [798]	validation_0-logloss:0.55648
# [799]	validation_0-logloss:0.55647
# [800]	validation_0-logloss:0.55646
# [801]	validation_0-logloss:0.55646
# [802]	validation_0-logloss:0.55645
# [803]	validation_0-logloss:0.55644
# [804]	validation_0-logloss:0.55644
# [805]	validation_0-logloss:0.55645
# [806]	validation_0-logloss:0.55644
# [807]	validation_0-logloss:0.55643
# [808]	validation_0-logloss:0.55642
# [809]	validation_0-logloss:0.55641
# [810]	validation_0-logloss:0.55644
# [811]	validation_0-logloss:0.55643
# [812]	validation_0-logloss:0.55642
# [813]	validation_0-logloss:0.55641
# [814]	validation_0-logloss:0.55640
# [815]	validation_0-logloss:0.55640
# [816]	validation_0-logloss:0.55639
# [817]	validation_0-logloss:0.55639
# [818]	validation_0-logloss:0.55639
# [819]	validation_0-logloss:0.55638
# [820]	validation_0-logloss:0.55637
# [821]	validation_0-logloss:0.55640
# [822]	validation_0-logloss:0.55639
# [823]	validation_0-logloss:0.55638
# [824]	validation_0-logloss:0.55639
# [825]	validation_0-logloss:0.55637
# [826]	validation_0-logloss:0.55637
# [827]	validation_0-logloss:0.55636
# [828]	validation_0-logloss:0.55635
# [829]	validation_0-logloss:0.55637
# [830]	validation_0-logloss:0.55636
# [831]	validation_0-logloss:0.55636
# [832]	validation_0-logloss:0.55635
# [833]	validation_0-logloss:0.55634
# [834]	validation_0-logloss:0.55633
# [835]	validation_0-logloss:0.55633
# [836]	validation_0-logloss:0.55632
# [837]	validation_0-logloss:0.55631
# [838]	validation_0-logloss:0.55631
# [839]	validation_0-logloss:0.55630
# [840]	validation_0-logloss:0.55629
# [841]	validation_0-logloss:0.55629
# [842]	validation_0-logloss:0.55628
# [843]	validation_0-logloss:0.55628
# [844]	validation_0-logloss:0.55627
# [845]	validation_0-logloss:0.55626
# [846]	validation_0-logloss:0.55625
# [847]	validation_0-logloss:0.55625
# [848]	validation_0-logloss:0.55624
# [849]	validation_0-logloss:0.55624
# [850]	validation_0-logloss:0.55623
# [851]	validation_0-logloss:0.55623
# [852]	validation_0-logloss:0.55622
# [853]	validation_0-logloss:0.55621
# [854]	validation_0-logloss:0.55621
# [855]	validation_0-logloss:0.55620
# [856]	validation_0-logloss:0.55619
# [857]	validation_0-logloss:0.55618
# [858]	validation_0-logloss:0.55617
# [859]	validation_0-logloss:0.55617
# [860]	validation_0-logloss:0.55616
# [861]	validation_0-logloss:0.55616
# [862]	validation_0-logloss:0.55615
# [863]	validation_0-logloss:0.55614
# [864]	validation_0-logloss:0.55613
# [865]	validation_0-logloss:0.55612
# [866]	validation_0-logloss:0.55611
# [867]	validation_0-logloss:0.55611
# [868]	validation_0-logloss:0.55610
# [869]	validation_0-logloss:0.55610
# [870]	validation_0-logloss:0.55609
# [871]	validation_0-logloss:0.55607
# [872]	validation_0-logloss:0.55607
# [873]	validation_0-logloss:0.55606
# [874]	validation_0-logloss:0.55605
# [875]	validation_0-logloss:0.55605
# [876]	validation_0-logloss:0.55604
# [877]	validation_0-logloss:0.55603
# [878]	validation_0-logloss:0.55602
# [879]	validation_0-logloss:0.55602
# [880]	validation_0-logloss:0.55601
# [881]	validation_0-logloss:0.55601
# [882]	validation_0-logloss:0.55601
# [883]	validation_0-logloss:0.55600
# [884]	validation_0-logloss:0.55599
# [885]	validation_0-logloss:0.55598
# [886]	validation_0-logloss:0.55598
# [887]	validation_0-logloss:0.55597
# [888]	validation_0-logloss:0.55596
# [889]	validation_0-logloss:0.55595
# [890]	validation_0-logloss:0.55594
# [891]	validation_0-logloss:0.55594
# [892]	validation_0-logloss:0.55593
# [893]	validation_0-logloss:0.55592
# [894]	validation_0-logloss:0.55592
# [895]	validation_0-logloss:0.55591
# [896]	validation_0-logloss:0.55591
# [897]	validation_0-logloss:0.55590
# [898]	validation_0-logloss:0.55590
# [899]	validation_0-logloss:0.55589
# [900]	validation_0-logloss:0.55589
# [901]	validation_0-logloss:0.55588
# [902]	validation_0-logloss:0.55587
# [903]	validation_0-logloss:0.55587
# [904]	validation_0-logloss:0.55586
# [905]	validation_0-logloss:0.55585
# [906]	validation_0-logloss:0.55585
# [907]	validation_0-logloss:0.55584
# [908]	validation_0-logloss:0.55582
# [909]	validation_0-logloss:0.55582
# [910]	validation_0-logloss:0.55581
# [911]	validation_0-logloss:0.55581
# [912]	validation_0-logloss:0.55580
# [913]	validation_0-logloss:0.55579
# [914]	validation_0-logloss:0.55579
# [915]	validation_0-logloss:0.55578
# [916]	validation_0-logloss:0.55578
# [917]	validation_0-logloss:0.55577
# [918]	validation_0-logloss:0.55576
# [919]	validation_0-logloss:0.55575
# [920]	validation_0-logloss:0.55574
# [921]	validation_0-logloss:0.55573
# [922]	validation_0-logloss:0.55572
# [923]	validation_0-logloss:0.55571
# [924]	validation_0-logloss:0.55572
# [925]	validation_0-logloss:0.55571
# [926]	validation_0-logloss:0.55570
# [927]	validation_0-logloss:0.55569
# [928]	validation_0-logloss:0.55569
# [929]	validation_0-logloss:0.55568
# [930]	validation_0-logloss:0.55567
# [931]	validation_0-logloss:0.55568
# [932]	validation_0-logloss:0.55567
# [933]	validation_0-logloss:0.55566
# [934]	validation_0-logloss:0.55566
# [935]	validation_0-logloss:0.55565
# [936]	validation_0-logloss:0.55565
# [937]	validation_0-logloss:0.55564
# [938]	validation_0-logloss:0.55564
# [939]	validation_0-logloss:0.55563
# [940]	validation_0-logloss:0.55563
# [941]	validation_0-logloss:0.55561
# [942]	validation_0-logloss:0.55560
# [943]	validation_0-logloss:0.55560
# [944]	validation_0-logloss:0.55559
# [945]	validation_0-logloss:0.55558
# [946]	validation_0-logloss:0.55558
# [947]	validation_0-logloss:0.55557
# [948]	validation_0-logloss:0.55556
# [949]	validation_0-logloss:0.55555
# [950]	validation_0-logloss:0.55555
# [951]	validation_0-logloss:0.55554
# [952]	validation_0-logloss:0.55554
# [953]	validation_0-logloss:0.55553
# [954]	validation_0-logloss:0.55552
# [955]	validation_0-logloss:0.55551
# [956]	validation_0-logloss:0.55551
# [957]	validation_0-logloss:0.55550
# [958]	validation_0-logloss:0.55549
# [959]	validation_0-logloss:0.55549
# [960]	validation_0-logloss:0.55548
# [961]	validation_0-logloss:0.55547
# [962]	validation_0-logloss:0.55546
# [963]	validation_0-logloss:0.55546
# [964]	validation_0-logloss:0.55545
# [965]	validation_0-logloss:0.55545
# [966]	validation_0-logloss:0.55544
# [967]	validation_0-logloss:0.55544
# [968]	validation_0-logloss:0.55543
# [969]	validation_0-logloss:0.55543
# [970]	validation_0-logloss:0.55542
# [971]	validation_0-logloss:0.55541
# [972]	validation_0-logloss:0.55541
# [973]	validation_0-logloss:0.55540
# [974]	validation_0-logloss:0.55539
# [975]	validation_0-logloss:0.55538
# [976]	validation_0-logloss:0.55538
# [977]	validation_0-logloss:0.55537
# [978]	validation_0-logloss:0.55536
# [979]	validation_0-logloss:0.55536
# [980]	validation_0-logloss:0.55536
# [981]	validation_0-logloss:0.55535
# [982]	validation_0-logloss:0.55534
# [983]	validation_0-logloss:0.55534
# [984]	validation_0-logloss:0.55533
# [985]	validation_0-logloss:0.55533
# [986]	validation_0-logloss:0.55532
# [987]	validation_0-logloss:0.55531
# [988]	validation_0-logloss:0.55530
# [989]	validation_0-logloss:0.55529
# [990]	validation_0-logloss:0.55529
# [991]	validation_0-logloss:0.55528
# [992]	validation_0-logloss:0.55527
# [993]	validation_0-logloss:0.55527
# [994]	validation_0-logloss:0.55527
# [995]	validation_0-logloss:0.55526
# [996]	validation_0-logloss:0.55525
# [997]	validation_0-logloss:0.55524
# [998]	validation_0-logloss:0.55524
# [999]	validation_0-logloss:0.55523
# [1000]	validation_0-logloss:0.55523
# [1001]	validation_0-logloss:0.55522
# [1002]	validation_0-logloss:0.55521
# [1003]	validation_0-logloss:0.55521
# [1004]	validation_0-logloss:0.55520
# [1005]	validation_0-logloss:0.55519
# [1006]	validation_0-logloss:0.55519
# [1007]	validation_0-logloss:0.55519
# [1008]	validation_0-logloss:0.55518
# [1009]	validation_0-logloss:0.55517
# [1010]	validation_0-logloss:0.55518
# [1011]	validation_0-logloss:0.55517
# [1012]	validation_0-logloss:0.55517
# [1013]	validation_0-logloss:0.55516
# [1014]	validation_0-logloss:0.55515
# [1015]	validation_0-logloss:0.55514
# [1016]	validation_0-logloss:0.55514
# [1017]	validation_0-logloss:0.55513
# [1018]	validation_0-logloss:0.55512
# [1019]	validation_0-logloss:0.55512
# [1020]	validation_0-logloss:0.55511
# [1021]	validation_0-logloss:0.55510
# [1022]	validation_0-logloss:0.55510
# [1023]	validation_0-logloss:0.55509
# [1024]	validation_0-logloss:0.55509
# [1025]	validation_0-logloss:0.55508
# [1026]	validation_0-logloss:0.55507
# [1027]	validation_0-logloss:0.55507
# [1028]	validation_0-logloss:0.55506
# [1029]	validation_0-logloss:0.55505
# [1030]	validation_0-logloss:0.55505
# [1031]	validation_0-logloss:0.55505
# [1032]	validation_0-logloss:0.55504
# [1033]	validation_0-logloss:0.55503
# [1034]	validation_0-logloss:0.55502
# [1035]	validation_0-logloss:0.55501
# [1036]	validation_0-logloss:0.55501
# [1037]	validation_0-logloss:0.55501
# [1038]	validation_0-logloss:0.55500
# [1039]	validation_0-logloss:0.55499
# [1040]	validation_0-logloss:0.55498
# [1041]	validation_0-logloss:0.55497
# [1042]	validation_0-logloss:0.55497
# [1043]	validation_0-logloss:0.55496
# [1044]	validation_0-logloss:0.55496
# [1045]	validation_0-logloss:0.55495
# [1046]	validation_0-logloss:0.55494
# [1047]	validation_0-logloss:0.55494
# [1048]	validation_0-logloss:0.55493
# [1049]	validation_0-logloss:0.55493
# [1050]	validation_0-logloss:0.55493
# [1051]	validation_0-logloss:0.55492
# [1052]	validation_0-logloss:0.55492
# [1053]	validation_0-logloss:0.55491
# [1054]	validation_0-logloss:0.55490
# [1055]	validation_0-logloss:0.55490
# [1056]	validation_0-logloss:0.55489
# [1057]	validation_0-logloss:0.55488
# [1058]	validation_0-logloss:0.55488
# [1059]	validation_0-logloss:0.55487
# [1060]	validation_0-logloss:0.55487
# [1061]	validation_0-logloss:0.55486
# [1062]	validation_0-logloss:0.55485
# [1063]	validation_0-logloss:0.55485
# [1064]	validation_0-logloss:0.55486
# [1065]	validation_0-logloss:0.55485
# [1066]	validation_0-logloss:0.55484
# [1067]	validation_0-logloss:0.55485
# [1068]	validation_0-logloss:0.55485
# [1069]	validation_0-logloss:0.55483
# [1070]	validation_0-logloss:0.55483
# [1071]	validation_0-logloss:0.55482
# [1072]	validation_0-logloss:0.55484
# [1073]	validation_0-logloss:0.55483
# [1074]	validation_0-logloss:0.55483
# [1075]	validation_0-logloss:0.55482
# [1076]	validation_0-logloss:0.55482
# [1077]	validation_0-logloss:0.55481
# [1078]	validation_0-logloss:0.55480
# [1079]	validation_0-logloss:0.55480
# [1080]	validation_0-logloss:0.55480
# [1081]	validation_0-logloss:0.55479
# [1082]	validation_0-logloss:0.55479
# [1083]	validation_0-logloss:0.55478
# [1084]	validation_0-logloss:0.55477
# [1085]	validation_0-logloss:0.55477
# [1086]	validation_0-logloss:0.55475
# [1087]	validation_0-logloss:0.55474
# [1088]	validation_0-logloss:0.55474
# [1089]	validation_0-logloss:0.55473
# [1090]	validation_0-logloss:0.55473
# [1091]	validation_0-logloss:0.55473
# [1092]	validation_0-logloss:0.55473
# [1093]	validation_0-logloss:0.55472
# [1094]	validation_0-logloss:0.55473
# [1095]	validation_0-logloss:0.55472
# [1096]	validation_0-logloss:0.55472
# [1097]	validation_0-logloss:0.55471
# [1098]	validation_0-logloss:0.55470
# [1099]	validation_0-logloss:0.55470
# [1100]	validation_0-logloss:0.55468
# [1101]	validation_0-logloss:0.55468
# [1102]	validation_0-logloss:0.55467
# [1103]	validation_0-logloss:0.55467
# [1104]	validation_0-logloss:0.55466
# [1105]	validation_0-logloss:0.55466
# [1106]	validation_0-logloss:0.55465
# [1107]	validation_0-logloss:0.55465
# [1108]	validation_0-logloss:0.55464
# [1109]	validation_0-logloss:0.55463
# [1110]	validation_0-logloss:0.55463
# [1111]	validation_0-logloss:0.55462
# [1112]	validation_0-logloss:0.55462
# [1113]	validation_0-logloss:0.55463
# [1114]	validation_0-logloss:0.55462
# [1115]	validation_0-logloss:0.55461
# [1116]	validation_0-logloss:0.55462
# [1117]	validation_0-logloss:0.55462
# [1118]	validation_0-logloss:0.55461
# [1119]	validation_0-logloss:0.55460
# [1120]	validation_0-logloss:0.55459
# [1121]	validation_0-logloss:0.55459
# [1122]	validation_0-logloss:0.55458
# [1123]	validation_0-logloss:0.55458
# [1124]	validation_0-logloss:0.55457
# [1125]	validation_0-logloss:0.55456
# [1126]	validation_0-logloss:0.55456
# [1127]	validation_0-logloss:0.55455
# [1128]	validation_0-logloss:0.55455
# [1129]	validation_0-logloss:0.55454
# [1130]	validation_0-logloss:0.55454
# [1131]	validation_0-logloss:0.55454
# [1132]	validation_0-logloss:0.55453
# [1133]	validation_0-logloss:0.55453
# [1134]	validation_0-logloss:0.55452
# [1135]	validation_0-logloss:0.55452
# [1136]	validation_0-logloss:0.55451
# [1137]	validation_0-logloss:0.55451
# [1138]	validation_0-logloss:0.55451
# [1139]	validation_0-logloss:0.55450
# [1140]	validation_0-logloss:0.55449
# [1141]	validation_0-logloss:0.55450
# [1142]	validation_0-logloss:0.55449
# [1143]	validation_0-logloss:0.55448
# [1144]	validation_0-logloss:0.55447
# [1145]	validation_0-logloss:0.55447
# [1146]	validation_0-logloss:0.55447
# [1147]	validation_0-logloss:0.55446
# [1148]	validation_0-logloss:0.55447
# [1149]	validation_0-logloss:0.55446
# [1150]	validation_0-logloss:0.55445
# [1151]	validation_0-logloss:0.55445
# [1152]	validation_0-logloss:0.55445
# [1153]	validation_0-logloss:0.55444
# [1154]	validation_0-logloss:0.55444
# [1155]	validation_0-logloss:0.55444
# [1156]	validation_0-logloss:0.55443
# [1157]	validation_0-logloss:0.55442
# [1158]	validation_0-logloss:0.55442
# [1159]	validation_0-logloss:0.55441
# [1160]	validation_0-logloss:0.55442
# [1161]	validation_0-logloss:0.55441
# [1162]	validation_0-logloss:0.55441
# [1163]	validation_0-logloss:0.55441
# [1164]	validation_0-logloss:0.55440
# [1165]	validation_0-logloss:0.55441
# [1166]	validation_0-logloss:0.55440
# [1167]	validation_0-logloss:0.55439
# [1168]	validation_0-logloss:0.55438
# [1169]	validation_0-logloss:0.55437
# [1170]	validation_0-logloss:0.55438
# [1171]	validation_0-logloss:0.55437
# [1172]	validation_0-logloss:0.55437
# [1173]	validation_0-logloss:0.55437
# [1174]	validation_0-logloss:0.55436
# [1175]	validation_0-logloss:0.55436
# [1176]	validation_0-logloss:0.55435
# [1177]	validation_0-logloss:0.55436
# [1178]	validation_0-logloss:0.55435
# [1179]	validation_0-logloss:0.55434
# [1180]	validation_0-logloss:0.55434
# [1181]	validation_0-logloss:0.55434
# [1182]	validation_0-logloss:0.55434
# [1183]	validation_0-logloss:0.55433
# [1184]	validation_0-logloss:0.55432
# [1185]	validation_0-logloss:0.55432
# [1186]	validation_0-logloss:0.55431
# [1187]	validation_0-logloss:0.55432
# [1188]	validation_0-logloss:0.55431
# [1189]	validation_0-logloss:0.55431
# [1190]	validation_0-logloss:0.55431
# [1191]	validation_0-logloss:0.55429
# [1192]	validation_0-logloss:0.55429
# [1193]	validation_0-logloss:0.55428
# [1194]	validation_0-logloss:0.55428
# [1195]	validation_0-logloss:0.55427
# [1196]	validation_0-logloss:0.55427
# [1197]	validation_0-logloss:0.55427
# [1198]	validation_0-logloss:0.55426
# [1199]	validation_0-logloss:0.55427
# [1200]	validation_0-logloss:0.55427
# [1201]	validation_0-logloss:0.55426
# [1202]	validation_0-logloss:0.55425
# [1203]	validation_0-logloss:0.55424
# [1204]	validation_0-logloss:0.55425
# [1205]	validation_0-logloss:0.55424
# [1206]	validation_0-logloss:0.55425
# [1207]	validation_0-logloss:0.55424
# [1208]	validation_0-logloss:0.55424
# [1209]	validation_0-logloss:0.55424
# [1210]	validation_0-logloss:0.55423
# [1211]	validation_0-logloss:0.55422
# [1212]	validation_0-logloss:0.55422
# [1213]	validation_0-logloss:0.55421
# [1214]	validation_0-logloss:0.55421
# [1215]	validation_0-logloss:0.55420
# [1216]	validation_0-logloss:0.55420
# [1217]	validation_0-logloss:0.55419
# [1218]	validation_0-logloss:0.55419
# [1219]	validation_0-logloss:0.55419
# [1220]	validation_0-logloss:0.55418
# [1221]	validation_0-logloss:0.55418
# [1222]	validation_0-logloss:0.55417
# [1223]	validation_0-logloss:0.55417
# [1224]	validation_0-logloss:0.55417
# [1225]	validation_0-logloss:0.55417
# [1226]	validation_0-logloss:0.55417
# [1227]	validation_0-logloss:0.55416
# [1228]	validation_0-logloss:0.55416
# [1229]	validation_0-logloss:0.55415
# [1230]	validation_0-logloss:0.55415
# [1231]	validation_0-logloss:0.55415
# [1232]	validation_0-logloss:0.55414
# [1233]	validation_0-logloss:0.55414
# [1234]	validation_0-logloss:0.55414
# [1235]	validation_0-logloss:0.55414
# [1236]	validation_0-logloss:0.55413
# [1237]	validation_0-logloss:0.55412
# [1238]	validation_0-logloss:0.55412
# [1239]	validation_0-logloss:0.55412
# [1240]	validation_0-logloss:0.55411
# [1241]	validation_0-logloss:0.55410
# [1242]	validation_0-logloss:0.55409
# [1243]	validation_0-logloss:0.55409
# [1244]	validation_0-logloss:0.55408
# [1245]	validation_0-logloss:0.55409
# [1246]	validation_0-logloss:0.55408
# [1247]	validation_0-logloss:0.55407
# [1248]	validation_0-logloss:0.55407
# [1249]	validation_0-logloss:0.55407
# [1250]	validation_0-logloss:0.55407
# [1251]	validation_0-logloss:0.55407
# [1252]	validation_0-logloss:0.55406
# [1253]	validation_0-logloss:0.55407
# [1254]	validation_0-logloss:0.55406
# [1255]	validation_0-logloss:0.55407
# [1256]	validation_0-logloss:0.55406
# [1257]	validation_0-logloss:0.55406
# [1258]	validation_0-logloss:0.55406
# [1259]	validation_0-logloss:0.55405
# [1260]	validation_0-logloss:0.55405
# [1261]	validation_0-logloss:0.55404
# [1262]	validation_0-logloss:0.55405
# [1263]	validation_0-logloss:0.55403
# [1264]	validation_0-logloss:0.55403
# [1265]	validation_0-logloss:0.55403
# [1266]	validation_0-logloss:0.55402
# [1267]	validation_0-logloss:0.55402
# [1268]	validation_0-logloss:0.55401
# [1269]	validation_0-logloss:0.55402
# [1270]	validation_0-logloss:0.55401
# [1271]	validation_0-logloss:0.55400
# [1272]	validation_0-logloss:0.55401
# [1273]	validation_0-logloss:0.55400
# [1274]	validation_0-logloss:0.55400
# [1275]	validation_0-logloss:0.55400
# [1276]	validation_0-logloss:0.55400
# [1277]	validation_0-logloss:0.55399
# [1278]	validation_0-logloss:0.55398
# [1279]	validation_0-logloss:0.55397
# [1280]	validation_0-logloss:0.55397
# [1281]	validation_0-logloss:0.55396
# [1282]	validation_0-logloss:0.55397
# [1283]	validation_0-logloss:0.55396
# [1284]	validation_0-logloss:0.55395
# [1285]	validation_0-logloss:0.55394
# [1286]	validation_0-logloss:0.55394
# [1287]	validation_0-logloss:0.55394
# [1288]	validation_0-logloss:0.55393
# [1289]	validation_0-logloss:0.55393
# [1290]	validation_0-logloss:0.55392
# [1291]	validation_0-logloss:0.55392
# [1292]	validation_0-logloss:0.55392
# [1293]	validation_0-logloss:0.55391
# [1294]	validation_0-logloss:0.55392
# [1295]	validation_0-logloss:0.55393
# [1296]	validation_0-logloss:0.55393
# [1297]	validation_0-logloss:0.55392
# [1298]	validation_0-logloss:0.55391
# [1299]	validation_0-logloss:0.55391
# [1300]	validation_0-logloss:0.55391
# [1301]	validation_0-logloss:0.55390
# [1302]	validation_0-logloss:0.55390
# [1303]	validation_0-logloss:0.55389
# [1304]	validation_0-logloss:0.55390
# [1305]	validation_0-logloss:0.55389
# [1306]	validation_0-logloss:0.55390
# [1307]	validation_0-logloss:0.55389
# [1308]	validation_0-logloss:0.55388
# [1309]	validation_0-logloss:0.55388
# [1310]	validation_0-logloss:0.55387
# [1311]	validation_0-logloss:0.55387
# [1312]	validation_0-logloss:0.55387
# [1313]	validation_0-logloss:0.55386
# [1314]	validation_0-logloss:0.55387
# [1315]	validation_0-logloss:0.55386
# [1316]	validation_0-logloss:0.55386
# [1317]	validation_0-logloss:0.55386
# [1318]	validation_0-logloss:0.55385
# [1319]	validation_0-logloss:0.55384
# [1320]	validation_0-logloss:0.55383
# [1321]	validation_0-logloss:0.55382
# [1322]	validation_0-logloss:0.55382
# [1323]	validation_0-logloss:0.55382
# [1324]	validation_0-logloss:0.55382
# [1325]	validation_0-logloss:0.55382
# [1326]	validation_0-logloss:0.55381
# [1327]	validation_0-logloss:0.55381
# [1328]	validation_0-logloss:0.55381
# [1329]	validation_0-logloss:0.55380
# [1330]	validation_0-logloss:0.55381
# [1331]	validation_0-logloss:0.55381
# [1332]	validation_0-logloss:0.55380
# [1333]	validation_0-logloss:0.55380
# [1334]	validation_0-logloss:0.55380
# [1335]	validation_0-logloss:0.55379
# [1336]	validation_0-logloss:0.55379
# [1337]	validation_0-logloss:0.55378
# [1338]	validation_0-logloss:0.55378
# [1339]	validation_0-logloss:0.55379
# [1340]	validation_0-logloss:0.55378
# [1341]	validation_0-logloss:0.55378
# [1342]	validation_0-logloss:0.55377
# [1343]	validation_0-logloss:0.55378
# [1344]	validation_0-logloss:0.55377
# [1345]	validation_0-logloss:0.55376
# [1346]	validation_0-logloss:0.55377
# [1347]	validation_0-logloss:0.55376
# [1348]	validation_0-logloss:0.55376
# [1349]	validation_0-logloss:0.55375
# [1350]	validation_0-logloss:0.55374
# [1351]	validation_0-logloss:0.55375
# [1352]	validation_0-logloss:0.55374
# [1353]	validation_0-logloss:0.55375
# [1354]	validation_0-logloss:0.55374
# [1355]	validation_0-logloss:0.55373
# [1356]	validation_0-logloss:0.55372
# [1357]	validation_0-logloss:0.55373
# [1358]	validation_0-logloss:0.55372
# [1359]	validation_0-logloss:0.55371
# [1360]	validation_0-logloss:0.55371
# [1361]	validation_0-logloss:0.55371
# [1362]	validation_0-logloss:0.55370
# ...
# [2075]	validation_0-logloss:0.55221
# [2076]	validation_0-logloss:0.55221
# [2077]	validation_0-logloss:0.55220
# [2078]	validation_0-logloss:0.55219
# [2079]	validation_0-logloss:0.55220
# [2080]	validation_0-logloss:0.55219
# [2081]	validation_0-logloss:0.55220
# [2082]	validation_0-logloss:0.55220
# [2083]	validation_0-logloss:0.55222
# [2084]	validation_0-logloss:0.55221
# [2085]	validation_0-logloss:0.55221
# [2086]	validation_0-logloss:0.55222
# [2087]	validation_0-logloss:0.55221
# [2088]	validation_0-logloss:0.55220
# [2089]	validation_0-logloss:0.55221
# [2090]	validation_0-logloss:0.55221
# [2091]	validation_0-logloss:0.55221
# [2092]	validation_0-logloss:0.55220
# [2093]	validation_0-logloss:0.55219
# [2094]	validation_0-logloss:0.55220
# [2095]	validation_0-logloss:0.55219
# [2096]	validation_0-logloss:0.55219
# [2097]	validation_0-logloss:0.55218
# [2098]	validation_0-logloss:0.55218
# [2099]	validation_0-logloss:0.55218
# [2100]	validation_0-logloss:0.55217
# [2101]	validation_0-logloss:0.55216
# [2102]	validation_0-logloss:0.55217
# [2103]	validation_0-logloss:0.55215
# [2104]	validation_0-logloss:0.55216
# [2105]	validation_0-logloss:0.55215
# [2106]	validation_0-logloss:0.55216
# [2107]	validation_0-logloss:0.55215
# [2108]	validation_0-logloss:0.55215
# [2109]	validation_0-logloss:0.55215
# [2110]	validation_0-logloss:0.55214
# [2111]	validation_0-logloss:0.55215
# [2112]	validation_0-logloss:0.55214
# [2113]	validation_0-logloss:0.55214
# [2114]	validation_0-logloss:0.55213
# [2115]	validation_0-logloss:0.55214
# [2116]	validation_0-logloss:0.55213
# [2117]	validation_0-logloss:0.55213
# [2118]	validation_0-logloss:0.55213
# [2119]	validation_0-logloss:0.55212
# [2120]	validation_0-logloss:0.55212
# [2121]	validation_0-logloss:0.55211
# [2122]	validation_0-logloss:0.55212
# [2123]	validation_0-logloss:0.55211
# [2124]	validation_0-logloss:0.55213
# [2125]	validation_0-logloss:0.55213
# [2126]	validation_0-logloss:0.55212
# [2127]	validation_0-logloss:0.55211
# [2128]	validation_0-logloss:0.55211
# [2129]	validation_0-logloss:0.55210
# [2130]	validation_0-logloss:0.55212
# [2131]	validation_0-logloss:0.55212
# [2132]	validation_0-logloss:0.55212
# [2133]	validation_0-logloss:0.55212
# [2134]	validation_0-logloss:0.55211
# [2135]	validation_0-logloss:0.55213
# [2136]	validation_0-logloss:0.55212
# [2137]	validation_0-logloss:0.55213
# [2138]	validation_0-logloss:0.55212
# [2139]	validation_0-logloss:0.55212
# [2140]	validation_0-logloss:0.55211
# [2141]	validation_0-logloss:0.55212
# [2142]	validation_0-logloss:0.55211
# [2143]	validation_0-logloss:0.55211
# [2144]	validation_0-logloss:0.55210
# [2145]	validation_0-logloss:0.55211
# [2146]	validation_0-logloss:0.55210
# [2147]	validation_0-logloss:0.55209
# [2148]	validation_0-logloss:0.55209
# [2149]	validation_0-logloss:0.55209
# [2150]	validation_0-logloss:0.55208
# [2151]	validation_0-logloss:0.55208
# [2152]	validation_0-logloss:0.55207
# [2153]	validation_0-logloss:0.55209
# [2154]	validation_0-logloss:0.55209
# [2155]	validation_0-logloss:0.55208
# [2156]	validation_0-logloss:0.55208
# [2157]	validation_0-logloss:0.55207
# [2158]	validation_0-logloss:0.55208
# [2159]	validation_0-logloss:0.55207
# [2160]	validation_0-logloss:0.55208
# [2161]	validation_0-logloss:0.55207
# [2162]	validation_0-logloss:0.55207
# [2163]	validation_0-logloss:0.55206
# [2164]	validation_0-logloss:0.55206
# [2165]	validation_0-logloss:0.55206
# [2166]	validation_0-logloss:0.55208
# [2167]	validation_0-logloss:0.55207
# [2168]	validation_0-logloss:0.55207
# [2169]	validation_0-logloss:0.55206
# [2170]	validation_0-logloss:0.55205
# [2171]	validation_0-logloss:0.55205
# [2172]	validation_0-logloss:0.55205
# [2173]	validation_0-logloss:0.55205
# [2174]	validation_0-logloss:0.55205
# [2175]	validation_0-logloss:0.55205
# [2176]	validation_0-logloss:0.55204
# [2177]	validation_0-logloss:0.55205
# [2178]	validation_0-logloss:0.55204
# [2179]	validation_0-logloss:0.55203
# [2180]	validation_0-logloss:0.55203
# [2181]	validation_0-logloss:0.55205
# [2182]	validation_0-logloss:0.55204
# [2183]	validation_0-logloss:0.55204
# [2184]	validation_0-logloss:0.55205
# [2185]	validation_0-logloss:0.55204
# [2186]	validation_0-logloss:0.55203
# [2187]	validation_0-logloss:0.55204
# [2188]	validation_0-logloss:0.55203
# [2189]	validation_0-logloss:0.55203
# [2190]	validation_0-logloss:0.55203
# [2191]	validation_0-logloss:0.55202
# [2192]	validation_0-logloss:0.55203
# [2193]	validation_0-logloss:0.55202
# [2194]	validation_0-logloss:0.55202
# [2195]	validation_0-logloss:0.55202
# [2196]	validation_0-logloss:0.55201
# [2197]	validation_0-logloss:0.55200
# [2198]	validation_0-logloss:0.55200
# [2199]	validation_0-logloss:0.55199
# [2200]	validation_0-logloss:0.55199
# [2201]	validation_0-logloss:0.55200
# [2202]	validation_0-logloss:0.55200
# [2203]	validation_0-logloss:0.55199
# [2204]	validation_0-logloss:0.55198
# [2205]	validation_0-logloss:0.55197
# [2206]	validation_0-logloss:0.55196
# [2207]	validation_0-logloss:0.55198
# [2208]	validation_0-logloss:0.55198
# [2209]	validation_0-logloss:0.55198
# [2210]	validation_0-logloss:0.55198
# [2211]	validation_0-logloss:0.55198
# [2212]	validation_0-logloss:0.55197
# [2213]	validation_0-logloss:0.55197
# [2214]	validation_0-logloss:0.55197
# [2215]	validation_0-logloss:0.55197
# [2216]	validation_0-logloss:0.55196
# [2217]	validation_0-logloss:0.55198
# [2218]	validation_0-logloss:0.55197
# [2219]	validation_0-logloss:0.55198
# [2220]	validation_0-logloss:0.55197
# [2221]	validation_0-logloss:0.55196
# [2222]	validation_0-logloss:0.55196
# [2223]	validation_0-logloss:0.55196
# [2224]	validation_0-logloss:0.55196
# [2225]	validation_0-logloss:0.55195
# [2226]	validation_0-logloss:0.55195
# [2227]	validation_0-logloss:0.55195
# [2228]	validation_0-logloss:0.55195
# [2229]	validation_0-logloss:0.55195
# [2230]	validation_0-logloss:0.55195
# [2231]	validation_0-logloss:0.55194
# [2232]	validation_0-logloss:0.55195
# [2233]	validation_0-logloss:0.55194
# [2234]	validation_0-logloss:0.55193
# [2235]	validation_0-logloss:0.55193
# [2236]	validation_0-logloss:0.55193
# [2237]	validation_0-logloss:0.55193
# [2238]	validation_0-logloss:0.55192
# [2239]	validation_0-logloss:0.55193
# [2240]	validation_0-logloss:0.55193
# [2241]	validation_0-logloss:0.55192
# [2242]	validation_0-logloss:0.55191
# [2243]	validation_0-logloss:0.55193
# [2244]	validation_0-logloss:0.55192
# [2245]	validation_0-logloss:0.55193
# [2246]	validation_0-logloss:0.55192
# [2247]	validation_0-logloss:0.55192
# [2248]	validation_0-logloss:0.55192
# [2249]	validation_0-logloss:0.55191
# [2250]	validation_0-logloss:0.55191
# [2251]	validation_0-logloss:0.55190
# [2252]	validation_0-logloss:0.55189
# [2253]	validation_0-logloss:0.55189
# [2254]	validation_0-logloss:0.55188
# [2255]	validation_0-logloss:0.55188
# [2256]	validation_0-logloss:0.55189
# [2257]	validation_0-logloss:0.55188
# [2258]	validation_0-logloss:0.55187
# [2259]	validation_0-logloss:0.55187
# [2260]	validation_0-logloss:0.55189
# [2261]	validation_0-logloss:0.55188
# [2262]	validation_0-logloss:0.55188
# [2263]	validation_0-logloss:0.55190
# [2264]	validation_0-logloss:0.55190
# [2265]	validation_0-logloss:0.55190
# [2266]	validation_0-logloss:0.55189
# [2267]	validation_0-logloss:0.55189
# [2268]	validation_0-logloss:0.55189
# [2269]	validation_0-logloss:0.55188
# [2270]	validation_0-logloss:0.55187
# [2271]	validation_0-logloss:0.55187
# [2272]	validation_0-logloss:0.55186
# [2273]	validation_0-logloss:0.55187
# [2274]	validation_0-logloss:0.55186
# [2275]	validation_0-logloss:0.55188
# [2276]	validation_0-logloss:0.55188
# [2277]	validation_0-logloss:0.55188
# [2278]	validation_0-logloss:0.55189
# [2279]	validation_0-logloss:0.55188
# [2280]	validation_0-logloss:0.55188
# [2281]	validation_0-logloss:0.55187
# [2282]	validation_0-logloss:0.55188
# [2283]	validation_0-logloss:0.55187
# [2284]	validation_0-logloss:0.55186
# [2285]	validation_0-logloss:0.55186
# [2286]	validation_0-logloss:0.55186
# [2287]	validation_0-logloss:0.55185
# [2288]	validation_0-logloss:0.55186
# [2289]	validation_0-logloss:0.55185
# [2290]	validation_0-logloss:0.55184
# [2291]	validation_0-logloss:0.55184
# [2292]	validation_0-logloss:0.55183
# [2293]	validation_0-logloss:0.55183
# [2294]	validation_0-logloss:0.55182
# [2295]	validation_0-logloss:0.55182
# [2296]	validation_0-logloss:0.55181
# [2297]	validation_0-logloss:0.55180
# [2298]	validation_0-logloss:0.55181
# [2299]	validation_0-logloss:0.55180
# [2300]	validation_0-logloss:0.55180
# [2301]	validation_0-logloss:0.55180
# [2302]	validation_0-logloss:0.55179
# [2303]	validation_0-logloss:0.55179
# [2304]	validation_0-logloss:0.55179
# [2305]	validation_0-logloss:0.55179
# [2306]	validation_0-logloss:0.55178
# [2307]	validation_0-logloss:0.55180
# [2308]	validation_0-logloss:0.55180
# [2309]	validation_0-logloss:0.55182
# [2310]	validation_0-logloss:0.55181
# [2311]	validation_0-logloss:0.55180
# [2312]	validation_0-logloss:0.55180
# [2313]	validation_0-logloss:0.55180
# [2314]	validation_0-logloss:0.55181
# [2315]	validation_0-logloss:0.55180
# [2316]	validation_0-logloss:0.55179
# [2317]	validation_0-logloss:0.55180
# [2318]	validation_0-logloss:0.55179
# [2319]	validation_0-logloss:0.55180
# [2320]	validation_0-logloss:0.55179
# [2321]	validation_0-logloss:0.55179
# [2322]	validation_0-logloss:0.55179
# [2323]	validation_0-logloss:0.55179
# [2324]	validation_0-logloss:0.55179
# [2325]	validation_0-logloss:0.55179
# [2326]	validation_0-logloss:0.55178
# [2327]	validation_0-logloss:0.55178
# [2328]	validation_0-logloss:0.55177
# [2329]	validation_0-logloss:0.55176
# [2330]	validation_0-logloss:0.55177
# [2331]	validation_0-logloss:0.55176
# [2332]	validation_0-logloss:0.55178
# [2333]	validation_0-logloss:0.55177
# [2334]	validation_0-logloss:0.55177
# [2335]	validation_0-logloss:0.55176
# [2336]	validation_0-logloss:0.55178
# [2337]	validation_0-logloss:0.55178
# [2338]	validation_0-logloss:0.55178
# [2339]	validation_0-logloss:0.55177
# [2340]	validation_0-logloss:0.55177
# [2341]	validation_0-logloss:0.55176
# [2342]	validation_0-logloss:0.55175
# [2343]	validation_0-logloss:0.55176
# [2344]	validation_0-logloss:0.55175
# [2345]	validation_0-logloss:0.55176
# [2346]	validation_0-logloss:0.55175
# [2347]	validation_0-logloss:0.55176
# [2348]	validation_0-logloss:0.55175
# [2349]	validation_0-logloss:0.55175
# [2350]	validation_0-logloss:0.55175
# [2351]	validation_0-logloss:0.55174
# [2352]	validation_0-logloss:0.55173
# [2353]	validation_0-logloss:0.55173
# [2354]	validation_0-logloss:0.55173
# [2355]	validation_0-logloss:0.55173
# [2356]	validation_0-logloss:0.55172
# [2357]	validation_0-logloss:0.55172
# [2358]	validation_0-logloss:0.55171
# [2359]	validation_0-logloss:0.55171
# [2360]	validation_0-logloss:0.55170
# [2361]	validation_0-logloss:0.55170
# [2362]	validation_0-logloss:0.55169
# [2363]	validation_0-logloss:0.55171
# [2364]	validation_0-logloss:0.55171
# [2365]	validation_0-logloss:0.55170
# [2366]	validation_0-logloss:0.55171
# [2367]	validation_0-logloss:0.55171
# [2368]	validation_0-logloss:0.55171
# [2369]	validation_0-logloss:0.55171
# [2370]	validation_0-logloss:0.55171
# [2371]	validation_0-logloss:0.55171
# [2372]	validation_0-logloss:0.55171
# [2373]	validation_0-logloss:0.55171
# [2374]	validation_0-logloss:0.55170
# [2375]	validation_0-logloss:0.55172
# [2376]	validation_0-logloss:0.55171
# [2377]	validation_0-logloss:0.55172
# [2378]	validation_0-logloss:0.55171
# [2379]	validation_0-logloss:0.55173
# [2380]	validation_0-logloss:0.55172
# [2381]	validation_0-logloss:0.55173
# [2382]	validation_0-logloss:0.55172
# [2383]	validation_0-logloss:0.55173
# [2384]	validation_0-logloss:0.55172
# [2385]	validation_0-logloss:0.55172
# [2386]	validation_0-logloss:0.55172
# [2387]	validation_0-logloss:0.55171
# [2388]	validation_0-logloss:0.55171
# [2389]	validation_0-logloss:0.55170
# [2390]	validation_0-logloss:0.55169
# [2391]	validation_0-logloss:0.55168
# [2392]	validation_0-logloss:0.55168
# [2393]	validation_0-logloss:0.55168
# [2394]	validation_0-logloss:0.55167
# [2395]	validation_0-logloss:0.55167
# [2396]	validation_0-logloss:0.55166
# [2397]	validation_0-logloss:0.55166
# [2398]	validation_0-logloss:0.55166
# [2399]	validation_0-logloss:0.55165
# [2400]	validation_0-logloss:0.55165
# [2401]	validation_0-logloss:0.55164
# [2402]	validation_0-logloss:0.55163
# [2403]	validation_0-logloss:0.55164
# [2404]	validation_0-logloss:0.55163
# [2405]	validation_0-logloss:0.55163
# [2406]	validation_0-logloss:0.55163
# [2407]	validation_0-logloss:0.55163
# [2408]	validation_0-logloss:0.55163
# [2409]	validation_0-logloss:0.55162
# [2410]	validation_0-logloss:0.55164
# [2411]	validation_0-logloss:0.55163
# [2412]	validation_0-logloss:0.55163
# [2413]	validation_0-logloss:0.55163
# [2414]	validation_0-logloss:0.55163
# [2415]	validation_0-logloss:0.55162
# [2416]	validation_0-logloss:0.55163
# [2417]	validation_0-logloss:0.55162
# [2418]	validation_0-logloss:0.55162
# [2419]	validation_0-logloss:0.55162
# [2420]	validation_0-logloss:0.55161
# [2421]	validation_0-logloss:0.55160
# [2422]	validation_0-logloss:0.55161
# [2423]	validation_0-logloss:0.55159
# [2424]	validation_0-logloss:0.55161
# [2425]	validation_0-logloss:0.55161
# [2426]	validation_0-logloss:0.55161
# [2427]	validation_0-logloss:0.55160
# [2428]	validation_0-logloss:0.55162
# [2429]	validation_0-logloss:0.55162
# [2430]	validation_0-logloss:0.55162
# [2431]	validation_0-logloss:0.55162
# [2432]	validation_0-logloss:0.55161
# [2433]	validation_0-logloss:0.55161
# [2434]	validation_0-logloss:0.55160
# [2435]	validation_0-logloss:0.55161
# [2436]	validation_0-logloss:0.55160
# [2437]	validation_0-logloss:0.55160
# [2438]	validation_0-logloss:0.55160
# [2439]	validation_0-logloss:0.55160
# [2440]	validation_0-logloss:0.55159
# [2441]	validation_0-logloss:0.55160
# [2442]	validation_0-logloss:0.55159
# [2443]	validation_0-logloss:0.55161
# [2444]	validation_0-logloss:0.55160
# [2445]	validation_0-logloss:0.55161
# [2446]	validation_0-logloss:0.55160
# [2447]	validation_0-logloss:0.55160
# [2448]	validation_0-logloss:0.55160
# [2449]	validation_0-logloss:0.55159
# [2450]	validation_0-logloss:0.55158
# [2451]	validation_0-logloss:0.55159
# [2452]	validation_0-logloss:0.55158
# [2453]	validation_0-logloss:0.55159
# [2454]	validation_0-logloss:0.55158
# [2455]	validation_0-logloss:0.55158
# [2456]	validation_0-logloss:0.55158
# [2457]	validation_0-logloss:0.55157
# [2458]	validation_0-logloss:0.55157
# [2459]	validation_0-logloss:0.55156
# [2460]	validation_0-logloss:0.55157
# [2461]	validation_0-logloss:0.55156
# [2462]	validation_0-logloss:0.55156
# [2463]	validation_0-logloss:0.55155
# [2464]	validation_0-logloss:0.55155
# [2465]	validation_0-logloss:0.55154
# [2466]	validation_0-logloss:0.55155
# [2467]	validation_0-logloss:0.55154
# [2468]	validation_0-logloss:0.55154
# [2469]	validation_0-logloss:0.55155
# [2470]	validation_0-logloss:0.55154
# [2471]	validation_0-logloss:0.55156
# [2472]	validation_0-logloss:0.55155
# [2473]	validation_0-logloss:0.55156
# [2474]	validation_0-logloss:0.55155
# [2475]	validation_0-logloss:0.55154
# [2476]	validation_0-logloss:0.55154
# [2477]	validation_0-logloss:0.55154
# [2478]	validation_0-logloss:0.55153
# [2479]	validation_0-logloss:0.55154
# [2480]	validation_0-logloss:0.55153
# [2481]	validation_0-logloss:0.55152
# [2482]	validation_0-logloss:0.55153
# [2483]	validation_0-logloss:0.55152
# [2484]	validation_0-logloss:0.55152
# [2485]	validation_0-logloss:0.55151
# [2486]	validation_0-logloss:0.55151
# [2487]	validation_0-logloss:0.55153
# [2488]	validation_0-logloss:0.55152
# [2489]	validation_0-logloss:0.55154
# [2490]	validation_0-logloss:0.55153
# [2491]	validation_0-logloss:0.55153
# [2492]	validation_0-logloss:0.55152
# [2493]	validation_0-logloss:0.55151
# [2494]	validation_0-logloss:0.55152
# [2495]	validation_0-logloss:0.55151
# [2496]	validation_0-logloss:0.55152
# [2497]	validation_0-logloss:0.55152
# [2498]	validation_0-logloss:0.55152
# [2499]	validation_0-logloss:0.55151
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eta=0.01, gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.00999999978,
#               max_delta_step=0, max_depth=1, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=2500, n_jobs=12,
#               num_parallel_tree=1, predictor='auto', random_state=22,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=22,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
features
# Out:
#             feature  importance
# 0               SAG    0.332524
# 1               POM    0.190600
# 2               WLK    0.149173
# 3               MOR    0.118657
# 4          elo_diff    0.070761
# 5               RTH    0.051625
# 6               COL    0.038766
# 7  ordinal_elo_diff    0.037177
# 8               DOL    0.010718

# %%
pd.DataFrame({'feature': columns, 'importance': best_mod.feature_importances_}).sort_values(['importance'], 
                                                                                            ascending=False, 
                                                                                            ignore_index=True)
# Out:
#             feature  importance
# 0               SAG    0.394960
# 1               WLK    0.201112
# 2               MOR    0.102235
# 3               POM    0.102049
# 4          elo_diff    0.095618
# 5               COL    0.048535
# 6               RTH    0.037104
# 7               DOL    0.012037
# 8  ordinal_elo_diff    0.006349

# %%
import pickle

with open('../resources/models/XGBoost.pkl', 'wb') as handle:
    pickle.dump(best_mod, handle, protocol=pickle.HIGHEST_PROTOCOL)

'Done'
# Out:
# 'Done'

# %%
X_train.columns
# Out:
# Index(['elo_diff', 'ordinal_elo_diff', 'COL', 'DOL', 'MOR', 'POM', 'RTH',
#        'SAG', 'WLK'],
#       dtype='object')
