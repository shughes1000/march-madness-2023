# %%
import pandas as pd

df = pd.read_pickle('../resources/data/preprocessed/tournament_games_with_trueskill.pkl')

df.head()
# Out:
#    winner  season  day_number  team0  team1  prev_matchups  \
# 0       0    2011         134   1155   1412            NaN
# 1       0    2011         134   1421   1114            NaN
# 2       0    2011         135   1427   1106            NaN
# 3       0    2011         135   1433   1425            NaN
# 4       0    2011         136   1139   1330            NaN
#
#    common_opps_win_pct_diff    elo_diff  ordinal_elo_diff   BIH  ...   SAG  \
# 0                  0.000000   23.658444                -5   3.0  ...  11.0
# 1                       NaN  -58.217711                34  18.0  ...  52.0
# 2                       NaN -129.057955                61  85.0  ...  89.0
# 3                  0.166667  -44.819201                16   2.0  ... -15.0
# 4                  0.250000  139.996746               -28 -31.0  ...  -7.0
#
#     STH   WIL   WLK   WOB   WOL  starters_rating_diff  starters_mu_diff  \
# 0  15.0   4.0  13.0  -2.0 -12.0             -3.575624         -0.772009
# 1  80.0  27.0  83.0  22.0  48.0             -3.884351         -2.735707
# 2  87.0  92.0  67.0  77.0  77.0             -0.834332         -0.140258
# 3 -19.0   3.0   4.0   8.0  30.0              1.198212          0.238191
# 4 -21.0 -32.0 -14.0 -32.0 -26.0              7.400918          4.493212
#
#    team_rating_diff  team_mu_diff
# 0         -1.032339     -0.372233
# 1         -1.343698     -2.258720
# 2         -4.839278     -5.259440
# 3          1.276506      0.847245
# 4          0.248042      0.408685
#
# [5 rows x 34 columns]

# %%
temp = pd.read_pickle('../resources/data/preprocessed/tournament_games_with_starters.pkl')

df[['starters_diff', 'rating_diff']] = temp[['starters_diff', 'rating_diff']]

df
# Out:
#       winner  season  day_number  team0  team1  prev_matchups  \
# 0          0    2011         134   1155   1412            NaN
# 1          0    2011         134   1421   1114            NaN
# 2          0    2011         135   1427   1106            NaN
# 3          0    2011         135   1433   1425            NaN
# 4          0    2011         136   1139   1330            NaN
# ...      ...     ...         ...    ...    ...            ...
# 1467       1    2022         146   1274   1242            NaN
# 1468       1    2022         146   1389   1314            NaN
# 1469       1    2022         152   1437   1242            NaN
# 1470       1    2022         152   1181   1314            0.5
# 1471       1    2022         154   1314   1242            NaN
#
#       common_opps_win_pct_diff    elo_diff  ordinal_elo_diff    BIH  ...  \
# 0                     0.000000   23.658444                -5    3.0  ...
# 1                          NaN  -58.217711                34   18.0  ...
# 2                          NaN -129.057955                61   85.0  ...
# 3                     0.166667  -44.819201                16    2.0  ...
# 4                     0.250000  139.996746               -28  -31.0  ...
# ...                        ...         ...               ...    ...  ...
# 1467                  0.000000  239.449424               -45  -42.0  ...
# 1468                       NaN  212.406858               -88 -102.0  ...
# 1469                 -0.083333    7.104325                -1   -5.0  ...
# 1470                 -0.094203  -85.575138                11   18.0  ...
# 1471                  0.000000  181.965084               -26  -26.0  ...
#
#         WIL   WLK    WOB   WOL  starters_rating_diff  starters_mu_diff  \
# 0       4.0  13.0   -2.0 -12.0             -3.575624         -0.772009
# 1      27.0  83.0   22.0  48.0             -3.884351         -2.735707
# 2      92.0  67.0   77.0  77.0             -0.834332         -0.140258
# 3       3.0   4.0    8.0  30.0              1.198212          0.238191
# 4     -32.0 -14.0  -32.0 -26.0              7.400918          4.493212
# ...     ...   ...    ...   ...                   ...               ...
# 1467  -42.0 -50.0  -45.0 -44.0              4.890063          4.291500
# 1468 -106.0 -83.0 -100.0 -93.0              4.329201          2.075027
# 1469   -2.0  -7.0   -3.0  -1.0             -1.186008         -1.436546
# 1470   21.0  15.0   19.0  18.0              2.312833          0.092446
# 1471  -34.0 -25.0  -32.0 -31.0              2.420453          3.271389
#
#       team_rating_diff  team_mu_diff  starters_diff  rating_diff
# 0            -1.032339     -0.372233      -0.471155    -0.439765
# 1            -1.343698     -2.258720      -1.066023    -0.768886
# 2            -4.839278     -5.259440      -0.842307    -0.872944
# 3             1.276506      0.847245       0.659763     0.436562
# 4             0.248042      0.408685       0.285695    -0.013491
# ...                ...           ...            ...          ...
# 1467          7.367290      7.180366       1.753633     1.419099
# 1468          8.500683      8.153979       1.360822     1.254796
# 1469          0.561097      0.383704       0.336114     0.252394
# 1470         -2.678379     -3.745747      -0.718734    -0.636140
# 1471          6.324323      6.708900       1.376670     1.040298
#
# [1472 rows x 36 columns]

# %%
df.sort_values(['season'], inplace=True, ignore_index=True)

df
# Out:
#       winner  season  day_number  team0  team1  prev_matchups  \
# 0          0    2011         134   1155   1412            NaN
# 1          1    2011         137   1427   1326            NaN
# 2          1    2011         137   1103   1323            NaN
# 3          1    2011         137   1254   1314            NaN
# 4          1    2011         137   1397   1276            NaN
# ...      ...     ...         ...    ...    ...            ...
# 1467       0    2022         139   1181   1277            NaN
# 1468       0    2022         139   1222   1228            NaN
# 1469       0    2022         139   1235   1458            NaN
# 1470       0    2022         138   1344   1350            NaN
# 1471       1    2022         154   1314   1242            NaN
#
#       common_opps_win_pct_diff    elo_diff  ordinal_elo_diff    BIH  ...  \
# 0                     0.000000   23.658444                -5    3.0  ...
# 1                          NaN  692.753169              -190 -196.0  ...
# 2                          NaN  400.507191              -100 -109.0  ...
# 3                     0.333333  222.856302               -51  -60.0  ...
# 4                     1.000000   49.396942               -20  -19.0  ...
# ...                        ...         ...               ...    ...  ...
# 1467                  0.000000  -97.442730                15   19.0  ...
# 1468                 -0.250000  -69.925376                11    7.0  ...
# 1469                  0.000000  156.221109               -34  -24.0  ...
# 1470                  0.000000 -204.129479                46   63.0  ...
# 1471                  0.000000  181.965084               -26  -26.0  ...
#
#         WIL    WLK    WOB    WOL  starters_rating_diff  starters_mu_diff  \
# 0       4.0   13.0   -2.0  -12.0             -3.575624         -0.772009
# 1    -211.0 -203.0 -212.0 -197.0             10.009965         10.591291
# 2    -112.0 -105.0 -110.0 -107.0              5.984485          6.247648
# 3     -80.0  -51.0  -71.0  -48.0              3.276087          2.381581
# 4     -18.0   -8.0  -13.0  -17.0              4.042951          2.830322
# ...     ...    ...    ...    ...                   ...               ...
# 1467   12.0   22.0   11.0   13.0              2.047491          0.389889
# 1468    3.0    9.0    8.0    8.0             -2.470832         -1.979676
# 1469  -21.0  -27.0  -29.0  -26.0              5.614480          4.489968
# 1470   68.0   47.0   59.0   61.0              2.725267          0.945359
# 1471  -34.0  -25.0  -32.0  -31.0              2.420453          3.271389
#
#       team_rating_diff  team_mu_diff  starters_diff  rating_diff
# 0            -1.032339     -0.372233      -0.471155    -0.439765
# 1            19.286530     20.304630       4.294945     3.633663
# 2            12.650698     13.018856       2.348856     1.976620
# 3             8.421755      7.373802       1.795538     1.364606
# 4            -0.797315     -0.844765       0.521876     0.104406
# ...                ...           ...            ...          ...
# 1467         -0.345423     -1.317902      -0.671443    -0.693030
# 1468         -0.548849     -1.139403      -0.690745    -0.627006
# 1469          3.756427      3.913220       0.417795     0.353467
# 1470         -4.211943     -4.866839      -0.678889    -0.589224
# 1471          6.324323      6.708900       1.376670     1.040298
#
# [1472 rows x 36 columns]

# %%
df.drop(columns=['day_number', 'team0', 'team1'], inplace=True)

df.head()
# Out:
#    winner  season  prev_matchups  common_opps_win_pct_diff    elo_diff  \
# 0       0    2011            NaN                  0.000000   23.658444
# 1       1    2011            NaN                       NaN  692.753169
# 2       1    2011            NaN                       NaN  400.507191
# 3       1    2011            NaN                  0.333333  222.856302
# 4       1    2011            NaN                  1.000000   49.396942
#
#    ordinal_elo_diff    BIH    COL    DCI    DOK  ...    WIL    WLK    WOB  \
# 0                -5    3.0  -14.0   38.0   38.0  ...    4.0   13.0   -2.0
# 1              -190 -196.0 -202.0 -166.0 -232.0  ... -211.0 -203.0 -212.0
# 2              -100 -109.0  -98.0  -84.0 -116.0  ... -112.0 -105.0 -110.0
# 3               -51  -60.0  -56.0 -134.0  -89.0  ...  -80.0  -51.0  -71.0
# 4               -20  -19.0   -6.0  -47.0  -18.0  ...  -18.0   -8.0  -13.0
#
#      WOL  starters_rating_diff  starters_mu_diff  team_rating_diff  \
# 0  -12.0             -3.575624         -0.772009         -1.032339
# 1 -197.0             10.009965         10.591291         19.286530
# 2 -107.0              5.984485          6.247648         12.650698
# 3  -48.0              3.276087          2.381581          8.421755
# 4  -17.0              4.042951          2.830322         -0.797315
#
#    team_mu_diff  starters_diff  rating_diff
# 0     -0.372233      -0.471155    -0.439765
# 1     20.304630       4.294945     3.633663
# 2     13.018856       2.348856     1.976620
# 3      7.373802       1.795538     1.364606
# 4     -0.844765       0.521876     0.104406
#
# [5 rows x 33 columns]

# %%
df = df[['winner', 'season', 'starters_rating_diff', 'starters_mu_diff', 
         'team_rating_diff', 'team_mu_diff', 
         'starters_diff', 'rating_diff']].copy()

df
# Out:
#       winner  season  starters_rating_diff  starters_mu_diff  \
# 0          0    2011             -3.575624         -0.772009
# 1          1    2011             10.009965         10.591291
# 2          1    2011              5.984485          6.247648
# 3          1    2011              3.276087          2.381581
# 4          1    2011              4.042951          2.830322
# ...      ...     ...                   ...               ...
# 1467       0    2022              2.047491          0.389889
# 1468       0    2022             -2.470832         -1.979676
# 1469       0    2022              5.614480          4.489968
# 1470       0    2022              2.725267          0.945359
# 1471       1    2022              2.420453          3.271389
#
#       team_rating_diff  team_mu_diff  starters_diff  rating_diff
# 0            -1.032339     -0.372233      -0.471155    -0.439765
# 1            19.286530     20.304630       4.294945     3.633663
# 2            12.650698     13.018856       2.348856     1.976620
# 3             8.421755      7.373802       1.795538     1.364606
# 4            -0.797315     -0.844765       0.521876     0.104406
# ...                ...           ...            ...          ...
# 1467         -0.345423     -1.317902      -0.671443    -0.693030
# 1468         -0.548849     -1.139403      -0.690745    -0.627006
# 1469          3.756427      3.913220       0.417795     0.353467
# 1470         -4.211943     -4.866839      -0.678889    -0.589224
# 1471          6.324323      6.708900       1.376670     1.040298
#
# [1472 rows x 8 columns]

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score, log_loss
# from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

predictions = []
feature_importances = []

for season in df['season'].unique():
    print(season)
    
    # s = MinMaxScaler()
    
    # split to in-sample and out-of-sample
    df_is = df.loc[~df['season'].isin([season]), :].reset_index(drop=True)
    df_oos = df.loc[df['season'].isin([season]), :].reset_index(drop=True)
    
    # train model
    eval_years = np.random.choice(df_is['season'].unique(), 5, replace=False)
    df_eval = df_is.loc[df_is['season'].isin(eval_years), :].reset_index(drop=True)
    df_train = df_is.loc[~df_is['season'].isin(eval_years), :].reset_index(drop=True)
    
    X_train = df_train.drop(columns=['winner', 'season'])
    # X_train = s.fit_transform(X_train)
    y_train = df_train['winner']
    
    X_eval = df_eval.drop(columns=['winner', 'season'])
    # X_eval = s.transform(X_eval)
    y_eval = df_eval['winner']    
    
    mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2000, 
                                    max_depth=1, eta=0.01)
    mod.fit(X_train, y_train, verbose=False, early_stopping_rounds=25, 
            eval_metric='logloss', eval_set=[(X_eval, y_eval)])
    
    
    # get out-of-sample predictions
    X_oos = df_oos.drop(columns=['winner', 'season'])
    # X_oos = s.transform(X_oos)
    y_oos = df_oos['winner']
    prediction = mod.predict_proba(X_oos)[:, 1]
    predictions.append(prediction)
    feature_importances.append(mod.feature_importances_)
    
    print(f"{season} Accuracy: {(y_oos == prediction.round()).mean():.2f}")
    print(f"{season} AUC: {roc_auc_score(y_oos, prediction):.2f}")
    print(f"{season} Logloss: {log_loss(y_oos, prediction):.2f}")
    
    print()
    
predictions = np.concatenate(predictions)
feature_importances = np.array(feature_importances).mean(axis=0)
    
'Done'
# Out:
# C:\Users\mhugh\anaconda3\envs\clean\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2011
# 2011 Accuracy: 0.64
# 2011 AUC: 0.71
# 2011 Logloss: 0.61
#
# 2012
# 2012 Accuracy: 0.76
# 2012 AUC: 0.79
# 2012 Logloss: 0.57
#
# 2013
# 2013 Accuracy: 0.67
# 2013 AUC: 0.72
# 2013 Logloss: 0.61
#
# 2014
# 2014 Accuracy: 0.69
# 2014 AUC: 0.75
# 2014 Logloss: 0.59
#
# 2015
# 2015 Accuracy: 0.76
# 2015 AUC: 0.83
# 2015 Logloss: 0.52
#
# 2016
# 2016 Accuracy: 0.73
# 2016 AUC: 0.80
# 2016 Logloss: 0.56
#
# 2017
# 2017 Accuracy: 0.71
# 2017 AUC: 0.79
# 2017 Logloss: 0.57
#
# 2018
# 2018 Accuracy: 0.69
# 2018 AUC: 0.76
# 2018 Logloss: 0.58
#
# 2019
# 2019 Accuracy: 0.72
# 2019 AUC: 0.83
# 2019 Logloss: 0.51
#
# 2021
# 2021 Accuracy: 0.65
# 2021 AUC: 0.71
# 2021 Logloss: 0.63
#
# 2022
# 2022 Accuracy: 0.66
# 2022 AUC: 0.72
# 2022 Logloss: 0.62
# 'Done'

# %%
(df['winner'] == predictions.round()).mean()
# Out:
# 0.6976902173913043

# %%
roc_auc_score(df['winner'], predictions)
# Out:
# 0.7660828213610587

# %%
log_loss(df['winner'], predictions)
# Out:
# 0.578662178752458

# %%
features = pd.DataFrame({'feature': X_oos.columns, 
                         'importance': feature_importances}).sort_values(['importance'], 
                                                                         ascending=False, 
                                                                         ignore_index=True)

features
# Out:
#                      feature  importance
# 0                        DCI    0.163849
# 1                        SAG    0.124990
# 2                        POM    0.118339
# 3           team_rating_diff    0.080667
# 4                        MOR    0.073478
# 5                rating_diff    0.064716
# 6                        LMC    0.061688
# 7                        DOK    0.052331
# 8              starters_diff    0.050780
# 9                   elo_diff    0.046445
# 10                       KPK    0.031681
# 11                       WLK    0.025302
# 12                       WIL    0.016921
# 13                       DUN    0.014441
# 14                       MAS    0.014107
# 15                       STH    0.010999
# 16                       COL    0.009609
# 17      starters_rating_diff    0.007900
# 18          starters_mu_diff    0.006260
# 19                       DOL    0.004542
# 20             prev_matchups    0.004481
# 21          ordinal_elo_diff    0.004296
# 22                       KRA    0.003304
# 23                       REW    0.003097
# 24                       RTH    0.001706
# 25                       WOL    0.001601
# 26                       WOB    0.001520
# 27  common_opps_win_pct_diff    0.000952
# 28                       BIH    0.000000
# 29              team_mu_diff    0.000000
# 30                       PGH    0.000000

# %%
df.drop(columns=features.loc[features['importance'] < 0.01, 'feature'], inplace=True)

df
# Out:
#       winner  season    elo_diff    DCI    DOK    DUN    KPK    LMC    MAS  \
# 0          0    2011   23.658444   38.0   38.0   40.0    9.0   26.0   15.0
# 1          1    2011  692.753169 -166.0 -232.0 -198.0 -211.0 -228.0 -200.0
# 2          1    2011  400.507191  -84.0 -116.0 -123.0 -110.0 -123.0 -113.0
# 3          1    2011  222.856302 -134.0  -89.0 -147.0  -79.0  -71.0  -66.0
# 4          1    2011   49.396942  -47.0  -18.0  -33.0   -4.0    4.0  -18.0
# ...      ...     ...         ...    ...    ...    ...    ...    ...    ...
# 1467       0    2022  -97.442730   13.0   34.0   30.0   19.0   22.0    8.0
# 1468       0    2022  -69.925376    5.0   10.0   14.0   11.0   15.0    5.0
# 1469       0    2022  156.221109  -42.0  -30.0  -41.0  -38.0   -1.0  -28.0
# 1470       0    2022 -204.129479   24.0   21.0   53.0   50.0    9.0   50.0
# 1471       1    2022  181.965084  -17.0  -22.0  -21.0  -24.0  -16.0  -26.0
#
#         MOR    POM    SAG    STH    WIL    WLK  team_rating_diff  \
# 0      46.0   32.0   11.0   15.0    4.0   13.0         -1.032339
# 1    -221.0 -218.0 -218.0 -190.0 -211.0 -203.0         19.286530
# 2    -103.0 -113.0 -119.0 -111.0 -112.0 -105.0         12.650698
# 3    -131.0 -107.0  -83.0  -71.0  -80.0  -51.0          8.421755
# 4     -33.0  -15.0  -13.0   -6.0  -18.0   -8.0         -0.797315
# ...     ...    ...    ...    ...    ...    ...               ...
# 1467   18.0   27.0   16.0   16.0   12.0   22.0         -0.345423
# 1468   15.0   12.0   10.0   10.0    3.0    9.0         -0.548849
# 1469  -19.0  -12.0  -40.0  -20.0  -21.0  -27.0          3.756427
# 1470   29.0   35.0   41.0   54.0   68.0   47.0         -4.211943
# 1471  -29.0  -24.0  -22.0  -29.0  -34.0  -25.0          6.324323
#
#       starters_diff  rating_diff
# 0         -0.471155    -0.439765
# 1          4.294945     3.633663
# 2          2.348856     1.976620
# 3          1.795538     1.364606
# 4          0.521876     0.104406
# ...             ...          ...
# 1467      -0.671443    -0.693030
# 1468      -0.690745    -0.627006
# 1469       0.417795     0.353467
# 1470      -0.678889    -0.589224
# 1471       1.376670     1.040298
#
# [1472 rows x 18 columns]

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score, log_loss
# from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

predictions = []
feature_importances = []

for season in df['season'].unique():
    print(season)
    
    # s = MinMaxScaler()
    
    # split to in-sample and out-of-sample
    df_is = df.loc[~df['season'].isin([season]), :].reset_index(drop=True)
    df_oos = df.loc[df['season'].isin([season]), :].reset_index(drop=True)
    
    # train model
    eval_years = np.random.choice(df_is['season'].unique(), 5, replace=False)
    df_eval = df_is.loc[df_is['season'].isin(eval_years), :].reset_index(drop=True)
    df_train = df_is.loc[~df_is['season'].isin(eval_years), :].reset_index(drop=True)
    
    X_train = df_train.drop(columns=['winner', 'season'])
    # X_train = s.fit_transform(X_train)
    y_train = df_train['winner']
    
    X_eval = df_eval.drop(columns=['winner', 'season'])
    # X_eval = s.transform(X_eval)
    y_eval = df_eval['winner']    
    
    mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2000, 
                                    max_depth=1, eta=0.01)
    mod.fit(X_train, y_train, verbose=False, early_stopping_rounds=25, 
            eval_metric='logloss', eval_set=[(X_eval, y_eval)])
    
    
    # get out-of-sample predictions
    X_oos = df_oos.drop(columns=['winner', 'season'])
    # X_oos = s.transform(X_oos)
    y_oos = df_oos['winner']
    prediction = mod.predict_proba(X_oos)[:, 1]
    predictions.append(prediction)
    feature_importances.append(mod.feature_importances_)
    
    print(f"{season} Accuracy: {(y_oos == prediction.round()).mean():.2f}")
    print(f"{season} AUC: {roc_auc_score(y_oos, prediction):.2f}")
    print(f"{season} Logloss: {log_loss(y_oos, prediction):.2f}")
    
    print()
    
predictions = np.concatenate(predictions)
feature_importances = np.array(feature_importances).mean(axis=0)
    
'Done'
# Out:
# 2011
# 2011 Accuracy: 0.64
# 2011 AUC: 0.72
# 2011 Logloss: 0.62
#
# 2012
# 2012 Accuracy: 0.73
# 2012 AUC: 0.80
# 2012 Logloss: 0.58
#
# 2013
# 2013 Accuracy: 0.69
# 2013 AUC: 0.72
# 2013 Logloss: 0.61
#
# 2014
# 2014 Accuracy: 0.67
# 2014 AUC: 0.75
# 2014 Logloss: 0.59
#
# 2015
# 2015 Accuracy: 0.77
# 2015 AUC: 0.83
# 2015 Logloss: 0.53
#
# 2016
# 2016 Accuracy: 0.75
# 2016 AUC: 0.82
# 2016 Logloss: 0.54
#
# 2017
# 2017 Accuracy: 0.69
# 2017 AUC: 0.78
# 2017 Logloss: 0.57
#
# 2018
# 2018 Accuracy: 0.67
# 2018 AUC: 0.76
# 2018 Logloss: 0.59
#
# 2019
# 2019 Accuracy: 0.75
# 2019 AUC: 0.86
# 2019 Logloss: 0.49
#
# 2021
# 2021 Accuracy: 0.63
# 2021 AUC: 0.70
# 2021 Logloss: 0.64
#
# 2022
# 2022 Accuracy: 0.69
# 2022 AUC: 0.71
# 2022 Logloss: 0.63
# 'Done'

# %%
(df['winner'] == predictions.round()).mean()
# Out:
# 0.6976902173913043

# %%
roc_auc_score(df['winner'], predictions)
# Out:
# 0.7628651494565218

# %%
log_loss(df['winner'], predictions)
# Out:
# 0.580583632832555

# %%
features = pd.DataFrame({'feature': X_oos.columns, 
                         'importance': feature_importances}).sort_values(['importance'], 
                                                                         ascending=False, 
                                                                         ignore_index=True)

features
# Out:
#              feature  importance
# 0                POM    0.194058
# 1                DCI    0.170902
# 2      starters_diff    0.117481
# 3                MOR    0.104865
# 4        rating_diff    0.091842
# 5           elo_diff    0.056910
# 6   team_rating_diff    0.055344
# 7                LMC    0.051798
# 8                SAG    0.043190
# 9                MAS    0.030775
# 10               DOK    0.024405
# 11               DUN    0.018861
# 12               WIL    0.015862
# 13               WLK    0.015122
# 14               STH    0.008586
# 15               KPK    0.000000

# %%
df.drop(columns=features.loc[features['importance'] < 0.01, 'feature'], inplace=True)

df
# Out:
#       winner  season    elo_diff    DCI    DOK    DUN    LMC    MAS    MOR  \
# 0          0    2011   23.658444   38.0   38.0   40.0   26.0   15.0   46.0
# 1          1    2011  692.753169 -166.0 -232.0 -198.0 -228.0 -200.0 -221.0
# 2          1    2011  400.507191  -84.0 -116.0 -123.0 -123.0 -113.0 -103.0
# 3          1    2011  222.856302 -134.0  -89.0 -147.0  -71.0  -66.0 -131.0
# 4          1    2011   49.396942  -47.0  -18.0  -33.0    4.0  -18.0  -33.0
# ...      ...     ...         ...    ...    ...    ...    ...    ...    ...
# 1467       0    2022  -97.442730   13.0   34.0   30.0   22.0    8.0   18.0
# 1468       0    2022  -69.925376    5.0   10.0   14.0   15.0    5.0   15.0
# 1469       0    2022  156.221109  -42.0  -30.0  -41.0   -1.0  -28.0  -19.0
# 1470       0    2022 -204.129479   24.0   21.0   53.0    9.0   50.0   29.0
# 1471       1    2022  181.965084  -17.0  -22.0  -21.0  -16.0  -26.0  -29.0
#
#         POM    SAG    WIL    WLK  team_rating_diff  starters_diff  rating_diff
# 0      32.0   11.0    4.0   13.0         -1.032339      -0.471155    -0.439765
# 1    -218.0 -218.0 -211.0 -203.0         19.286530       4.294945     3.633663
# 2    -113.0 -119.0 -112.0 -105.0         12.650698       2.348856     1.976620
# 3    -107.0  -83.0  -80.0  -51.0          8.421755       1.795538     1.364606
# 4     -15.0  -13.0  -18.0   -8.0         -0.797315       0.521876     0.104406
# ...     ...    ...    ...    ...               ...            ...          ...
# 1467   27.0   16.0   12.0   22.0         -0.345423      -0.671443    -0.693030
# 1468   12.0   10.0    3.0    9.0         -0.548849      -0.690745    -0.627006
# 1469  -12.0  -40.0  -21.0  -27.0          3.756427       0.417795     0.353467
# 1470   35.0   41.0   68.0   47.0         -4.211943      -0.678889    -0.589224
# 1471  -24.0  -22.0  -34.0  -25.0          6.324323       1.376670     1.040298
#
# [1472 rows x 16 columns]

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import roc_auc_score, log_loss
# from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

predictions = []
feature_importances = []

for season in df['season'].unique():
    print(season)
    
    # s = MinMaxScaler()
    
    # split to in-sample and out-of-sample
    df_is = df.loc[~df['season'].isin([season]), :].reset_index(drop=True)
    df_oos = df.loc[df['season'].isin([season]), :].reset_index(drop=True)
    
    # train model
    eval_years = np.random.choice(df_is['season'].unique(), 5, replace=False)
    df_eval = df_is.loc[df_is['season'].isin(eval_years), :].reset_index(drop=True)
    df_train = df_is.loc[~df_is['season'].isin(eval_years), :].reset_index(drop=True)
    
    X_train = df_train.drop(columns=['winner', 'season'])
    # X_train = s.fit_transform(X_train)
    y_train = df_train['winner']
    
    X_eval = df_eval.drop(columns=['winner', 'season'])
    # X_eval = s.transform(X_eval)
    y_eval = df_eval['winner']    
    
    mod = xgb.XGBClassifier(objective='binary:logistic', seed=22, n_estimators=2000, 
                                    max_depth=1, eta=0.01)
    mod.fit(X_train, y_train, verbose=False, early_stopping_rounds=25, 
            eval_metric='logloss', eval_set=[(X_eval, y_eval)])
    
    
    # get out-of-sample predictions
    X_oos = df_oos.drop(columns=['winner', 'season'])
    # X_oos = s.transform(X_oos)
    y_oos = df_oos['winner']
    prediction = mod.predict_proba(X_oos)[:, 1]
    predictions.append(prediction)
    feature_importances.append(mod.feature_importances_)
    
    print(f"{season} Accuracy: {(y_oos == prediction.round()).mean():.2f}")
    print(f"{season} AUC: {roc_auc_score(y_oos, prediction):.2f}")
    print(f"{season} Logloss: {log_loss(y_oos, prediction):.2f}")
    
    print()
    
predictions = np.concatenate(predictions)
feature_importances = np.array(feature_importances).mean(axis=0)
    
'Done'
# Out:
# 2011
# 2011 Accuracy: 0.67
# 2011 AUC: 0.75
# 2011 Logloss: 0.59
#
# 2012
# 2012 Accuracy: 0.70
# 2012 AUC: 0.75
# 2012 Logloss: 0.61
#
# 2013
# 2013 Accuracy: 0.67
# 2013 AUC: 0.72
# 2013 Logloss: 0.61
#
# 2014
# 2014 Accuracy: 0.69
# 2014 AUC: 0.74
# 2014 Logloss: 0.60
#
# 2015
# 2015 Accuracy: 0.75
# 2015 AUC: 0.82
# 2015 Logloss: 0.52
#
# 2016
# 2016 Accuracy: 0.75
# 2016 AUC: 0.79
# 2016 Logloss: 0.57
#
# 2017
# 2017 Accuracy: 0.66
# 2017 AUC: 0.80
# 2017 Logloss: 0.55
#
# 2018
# 2018 Accuracy: 0.69
# 2018 AUC: 0.76
# 2018 Logloss: 0.59
#
# 2019
# 2019 Accuracy: 0.73
# 2019 AUC: 0.85
# 2019 Logloss: 0.52
#
# 2021
# 2021 Accuracy: 0.65
# 2021 AUC: 0.70
# 2021 Logloss: 0.64
#
# 2022
# 2022 Accuracy: 0.64
# 2022 AUC: 0.72
# 2022 Logloss: 0.63
# 'Done'

# %%
(df['winner'] == predictions.round()).mean()
# Out:
# 0.6902173913043478

# %%
roc_auc_score(df['winner'], predictions)
# Out:
# 0.7606775756143669

# %%
log_loss(df['winner'], predictions)
# Out:
# 0.5834942218827327

# %%
features = pd.DataFrame({'feature': X_oos.columns, 
                         'importance': feature_importances}).sort_values(['importance'], 
                                                                         ascending=False, 
                                                                         ignore_index=True)

features
# Out:
#              feature  importance
# 0                DCI    0.172647
# 1                POM    0.131419
# 2   team_rating_diff    0.098359
# 3        rating_diff    0.093459
# 4                MAS    0.083417
# 5                MOR    0.077884
# 6                SAG    0.075738
# 7                LMC    0.070904
# 8      starters_diff    0.063944
# 9           elo_diff    0.053340
# 10               WLK    0.038185
# 11               DOK    0.030585
# 12               WIL    0.006866
# 13               DUN    0.003255

# %%
import seaborn as sns

sns.histplot(x=predictions)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df_acc = pd.read_pickle('../resources/data/preprocessed/tournament_games.pkl')[['winner', 'season', 'team0', 'team1']]

df_acc = df_acc.loc[df_acc['season'] >= 2011, :].copy()

df_acc.sort_values(['season'], inplace=True, ignore_index=True)

df_acc['prediction'] = predictions

df_acc
# Out:
#       winner  season  team0  team1  prediction
# 0          0    2011   1155   1412    0.368627
# 1          1    2011   1427   1326    0.850523
# 2          1    2011   1103   1323    0.850523
# 3          1    2011   1254   1314    0.850523
# 4          1    2011   1397   1276    0.631762
# ...      ...     ...    ...    ...         ...
# 1467       0    2022   1181   1277    0.371939
# 1468       0    2022   1222   1228    0.370247
# 1469       0    2022   1235   1458    0.627918
# 1470       0    2022   1344   1350    0.371939
# 1471       1    2022   1314   1242    0.632915
#
# [1472 rows x 5 columns]

# %%
df_seeds = pd.read_csv('../resources/data/unprocessed/MNCAATourneySeeds.csv')

df_seeds['Seed'] = df_seeds['Seed'].str.extract('(\d+)').astype(int)

df_seeds
# Out:
#       Season  Seed  TeamID
# 0       1985     1    1207
# 1       1985     2    1210
# 2       1985     3    1228
# 3       1985     4    1260
# 4       1985     5    1374
# ...      ...   ...     ...
# 2485    2023    12    1433
# 2486    2023    13    1233
# 2487    2023    14    1213
# 2488    2023    15    1421
# 2489    2023    16    1224
#
# [2490 rows x 3 columns]

# %%
df_acc['seed_diff'] = (df_acc.merge(df_seeds, how='left', 
                                    left_on=['season', 'team1'], 
                                    right_on=['Season', 'TeamID'])['Seed'] - 
                       df_acc.merge(df_seeds, how='left', 
                                    left_on=['season', 'team0'], 
                                    right_on=['Season', 'TeamID'])['Seed'])

df_acc
# Out:
#       winner  season  team0  team1  prediction  seed_diff
# 0          0    2011   1155   1412    0.368627          0
# 1          1    2011   1427   1326    0.850523        -15
# 2          1    2011   1103   1323    0.850523        -13
# 3          1    2011   1254   1314    0.850523        -13
# 4          1    2011   1397   1276    0.631762         -1
# ...      ...     ...    ...    ...         ...        ...
# 1467       0    2022   1181   1277    0.371939          5
# 1468       0    2022   1222   1228    0.370247         -1
# 1469       0    2022   1235   1458    0.627918         -8
# 1470       0    2022   1344   1350    0.371939          8
# 1471       1    2022   1314   1242    0.632915         -7
#
# [1472 rows x 6 columns]

# %%
df_acc['correct'] = df_acc['winner'] == df_acc['prediction'].round()

df_acc
# Out:
#       winner  season  team0  team1  prediction  seed_diff  correct
# 0          0    2011   1155   1412    0.368627          0     True
# 1          1    2011   1427   1326    0.850523        -15     True
# 2          1    2011   1103   1323    0.850523        -13     True
# 3          1    2011   1254   1314    0.850523        -13     True
# 4          1    2011   1397   1276    0.631762         -1     True
# ...      ...     ...    ...    ...         ...        ...      ...
# 1467       0    2022   1181   1277    0.371939          5     True
# 1468       0    2022   1222   1228    0.370247         -1     True
# 1469       0    2022   1235   1458    0.627918         -8    False
# 1470       0    2022   1344   1350    0.371939          8     True
# 1471       1    2022   1314   1242    0.632915         -7     True
#
# [1472 rows x 7 columns]

# %%
df_acc_by_seed = df_acc.groupby(['seed_diff'])['correct'].mean().round(2)

df_acc_by_seed
# Out:
# seed_diff
# -15    0.98
# -13    0.86
# -12    0.75
# -11    0.87
# -10    0.67
# -9     0.79
# -8     0.74
# -7     0.64
# -6     0.38
# -5     0.61
# -4     0.59
# -3     0.70
# -2     0.79
# -1     0.56
#  0     0.52
#  1     0.54
#  2     0.79
#  3     0.70
#  4     0.59
#  5     0.58
#  6     0.38
#  7     0.64
#  8     0.73
#  9     0.79
#  10    0.67
#  11    0.87
#  12    0.75
#  13    0.86
#  15    0.98
# Name: correct, dtype: float64

# %%
import matplotlib.pyplot as plt

ax = sns.barplot(x=df_acc_by_seed, y=df_acc_by_seed.index, 
                 orient='h', color='#45B6FE')

ax.bar_label(ax.containers[0])

plt.xlabel('Accuracy %')
plt.ylabel('Seed Difference')
plt.title('Accuracy by Seed Difference')

plt.show()
